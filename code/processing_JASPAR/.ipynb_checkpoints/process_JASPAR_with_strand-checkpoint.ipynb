# %%
# Import standard libraries
import os
from importlib import reload
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import pandas as pd
import pickle
import itertools
from itertools import groupby
import os.path
import math
import pybedtools
import time
from tqdm import tqdm
import random
import MOODS.parsers
import MOODS.tools
import MOODS.scan
import subprocess
# Custom libraries
import utils as lu
import process_jaspar_with_strand as pj
# Reload modules in case of modifications
reload(lu)
reload(pj)
# Out:
# <module 'process_jaspar_with_strand' from '/home/louiscam/projects/gpcr/code/JASPAR_processing/process_jaspar_with_strand.py'>

# %% [markdown]
# # Directories

# %%
# Directory of adhesome data
dir_adhesome = '/home/louiscam/projects/gpcr/data/adhesome_data/'
# Directory of genome data
dir_genome = '/home/louiscam/projects/gpcr/data/genome_data/'
prom_hg19_seq_dir = dir_genome+'prom_hg19_seq_dir/'
# Directory of processed HiC
dir_processed_hic = '/home/louiscam/projects/gpcr/save/processed_hic_data_dir/'
# Directory for storing preliminary results
prelim_results_dir = '/home/louiscam/projects/gpcr/save/prelim_results_dir/'
# Directory of epigenomic data
epigenome_dir = '/home/louiscam/projects/gpcr/data/epigenome_data/'
processed_epigenome_data_dir = '/home/louiscam/projects/gpcr/save/processed_epigenome_data_dir/'
# Saving directory
saving_dir = '/home/louiscam/projects/gpcr/save/figures/'
# Directory of tf data
tf_dir = '/home/louiscam/projects/gpcr/data/tf_data/'
jaspar_dir = tf_dir+'jaspar_data/'
pfm_dir = tf_dir+'pfm_data/'
fantom5_dir = '/home/louiscam/projects/gpcr/data/fantom5/'
moods_out_dir = tf_dir+'moods_cage_outdir_with_strand/'
cage_fasta_dir = dir_genome+'cage_hg19_seq_dir_with_strand/'

# %% [markdown]
# # 1. Select genes of interest

# %% [markdown]
# ### Load genes of interest (active adhesome genes)

# %%
# Genes of interest and location
selected_genes = pickle.load(open(saving_dir+'active_adhesome_genes.pkl', 'rb'))
print('Number of genes of interest = '+str(len(selected_genes)))
# Out:
# Number of genes of interest = 219

# %%
# Mapping UCSC to HGNC
ucsc_to_hgnc = pj.create_ucsc_hgnc_dict(dir_genome+'chrom_hg19.name')

# %% [markdown]
# ### Load human TFs list
# from http://humantfs.ccbr.utoronto.ca/

# %%
# Load TFs
tf_df = pd.read_csv(dir_genome+'human_tf.database', sep='\t', header=0, index_col=0)
tf_df = tf_df[tf_df['Is TF?']=='Yes'].sort_values(by=['HGNC symbol'])
all_tfs = tf_df['HGNC symbol'].values
print('Total number of TFs = '+str(len(all_tfs)))
# Out:
# Total number of TFs = 1639

# %% [markdown]
# ### Gene location

# %%
# Load gene locations
gene_locations_filename = dir_genome+'chrom_hg19.loc'
df_loc = pd.read_csv(gene_locations_filename, sep = '\t', header = 0)
df_loc.columns = ['transcript','chrom','strand','txStart','txEnd','cdsStart','cdsEnd',
                  'exonCount','exonStarts','exonEnds','proteinID','alignID']
df_loc['gene'] = [ucsc_to_hgnc[t] for t in df_loc['transcript']]
# Pick largest extent of each gene
min_extent_gene = df_loc.groupby(['gene'], sort=False)['txStart'].min().rename('tx_minStart')
max_extent_gene = df_loc.groupby(['gene'], sort=False)['txEnd'].max().rename('tx_maxEnd')
df_loc = pd.merge(df_loc, min_extent_gene, on='gene')
df_loc = pd.merge(df_loc, max_extent_gene, on='gene')
df_loc = df_loc[['transcript','gene','chrom','strand',
                 'tx_minStart','tx_maxEnd']]
# Determine the strand of the gene (in case of labeling error)
df_loc = pd.merge(df_loc, 
                  df_loc.groupby(['gene','chrom','tx_minStart','tx_maxEnd'])['strand'].count().rename('strand_vote'),
                  on=['gene','chrom','tx_minStart','tx_maxEnd'])
df_loc = df_loc.sort_values(by=['gene','strand_vote'])
df_loc = df_loc.drop_duplicates(subset=['gene','chrom','tx_minStart','tx_maxEnd'], keep='first')
df_loc['txLength'] = df_loc['tx_maxEnd']-df_loc['tx_minStart']
df_loc = df_loc[['gene','chrom','strand','tx_minStart','tx_maxEnd','txLength']]
df_loc.columns = ['gene','chrom','strand','txStart','txEnd','txLength']
# Restrict to genes of interest
df_loc = df_loc[df_loc['gene'].isin(selected_genes)]
df_loc['isTF'] = [df_loc.iloc[i,0] in all_tfs for i in range(df_loc.shape[0])]
df_loc.head()
# Out:
#        gene  chrom strand    txStart      txEnd  txLength   isTF
# 46268  ABI1  chr10      -   27035524   27150016    114492  False
# 13550  ABI2   chr2      +  204193002  204296892    103890  False
# 70810  ABI3  chr17      +   47287588   47300587     12999  False
# 41777  ABL1   chr9      +  133589267  133763062    173795  False
# 33033  ACTB   chr7      -    5566778    5570232      3454  False

# %%
# Visualize distribution of gene lengths
print('adhesome gene lengths quartile = '+str(np.quantile(df_loc['txLength'].values, [0.25,0.5,0.75])))
plt.figure()
plt.hist(df_loc['txLength'], bins=np.arange(0,1000000,5000))
plt.xlabel('gene length')
plt.ylabel('number of genes')
plt.title('histogram of adhesome gene lengths')
plt.show()
# Out:
# adhesome gene lengths quartile = [ 26394.  66588. 149211.]

# %% [markdown]
# ### Define gene window

# %%
# Define region 1kb upstream of transcripts
df_loc['gene_window_start'] = [df_loc['txStart'].iloc[i]-1000 if (df_loc['strand'].iloc[i]=='+') 
                             else max(df_loc['txStart'].iloc[i],df_loc['txStart'].iloc[i]-5000) for i in range(df_loc.shape[0])]
df_loc['gene_window_end'] = [min(df_loc['txEnd'].iloc[i], df_loc['txStart'].iloc[i]+5000) 
                             if (df_loc['strand'].iloc[i]=='+') 
                             else 
                             df_loc['txEnd'].iloc[i]+1000 
                             for i in range(df_loc.shape[0])]

# %%
# Visualize results
df_loc.head()
# Out:
#        gene  chrom strand    txStart      txEnd  txLength   isTF  \
# 46268  ABI1  chr10      -   27035524   27150016    114492  False
# 13550  ABI2   chr2      +  204193002  204296892    103890  False
# 70810  ABI3  chr17      +   47287588   47300587     12999  False
# 41777  ABL1   chr9      +  133589267  133763062    173795  False
# 33033  ACTB   chr7      -    5566778    5570232      3454  False
#
#        gene_window_start  gene_window_end
# 46268           27035524         27151016
# 13550          204192002        204198002
# 70810           47286588         47292588
# 41777          133588267        133594267
# 33033            5566778          5571232

# %% [markdown]
# # 2. Select CAGE peaks

# %% [markdown]
# ### Process robust CAGE peaks

# %%
# Load annotated FANTOM5 CAGE peaks
cage_df = pd.read_csv(fantom5_dir+'hg19.cage_peak_phase1and2combined_ann.txt', sep='\t', skiprows=7, header=0)
# Define new columns
cage_df['gene'] = cage_df['short_description'].str.split('@',expand=True)[1]
cage_df['chrom'] = cage_df['00Annotation'].str.split(':', expand=True)[0]
cage_df['cage_start'] = cage_df['00Annotation'].str.split(':', expand=True)[1].str.split(",", expand=True)[0].str.split(".", expand=True)[0].astype(int)
cage_df['cage_end'] = cage_df['00Annotation'].str.split(':', expand=True)[1].str.split(",", expand=True)[0].str.split(".", expand=True)[2].astype(int)
cage_df['strand'] = cage_df['00Annotation'].str.split(':', expand=True)[1].str.split(",", expand=True)[1]
cage_df['peak_id'] = cage_df['short_description'].str.split('@', expand=True)[0].str.strip('p')
# Reformat dataframe
cage_df = cage_df[['short_description', 'gene','association_with_transcript',
                   'chrom','cage_start','cage_end','strand','peak_id']]
cage_df = cage_df.sort_values(by=['chrom','cage_start'])
print('Number of unique CAGE peaks = '+str(len(np.unique(cage_df['short_description'].values))))
cage_df.head()
# Out:
# Number of unique CAGE peaks = 201802
#       short_description      gene    association_with_transcript chrom  \
# 95563       p1@MTND1P23  MTND1P23  129bp_to_ENST00000416931_5end  chr1
# 95564       p3@MTND1P23  MTND1P23  197bp_to_ENST00000416931_5end  chr1
# 95565       p3@MTND2P28  MTND2P28  246bp_to_ENST00000457540_5end  chr1
# 95566       p4@MTND2P28  MTND2P28  458bp_to_ENST00000457540_5end  chr1
# 95567       p1@MTND2P28  MTND2P28  489bp_to_ENST00000457540_5end  chr1
#
#        cage_start  cage_end strand peak_id
# 95563      564571    564600      +       1
# 95564      564639    564649      +       3
# 95565      565266    565278      +       3
# 95566      565478    565483      +       4
# 95567      565509    565541      +       1

# %%
# Check which genes are located on the opposite strand of their promoter (mislabeling error)
# The only problematic error was on PDPK1, which has been taken care of before
merge_df = pd.merge(df_loc[['gene','strand']],cage_df[['gene','strand']], on=['gene'], suffixes=['_gene','_prom'])
merge_df[merge_df['strand_gene'] != merge_df['strand_prom']].drop_duplicates(subset=['gene'])
# Out:
#      gene strand_gene strand_prom
# 279  CALR           +           -

# %% [markdown]
# ### CAGE peaks within selected gene windows

# %%
# Create bed file for regions upstream of genes of interest
gene_window_df = df_loc[['chrom','gene_window_start','gene_window_end','gene','strand']]
gene_window_df['score'] = 0
gene_window_df = gene_window_df[['chrom','gene_window_start','gene_window_end','gene','score','strand']]
gene_window_bed = pybedtools.BedTool.from_dataframe(gene_window_df).sort()

# %%
# Create a bed file for robust CAGE peaks
cage_peak_df = cage_df[['chrom','cage_start','cage_end','short_description','peak_id','strand']]
cage_bed = pybedtools.BedTool.from_dataframe(cage_peak_df).sort()

# %%
# Get CAGE peaks for each gene of interest
out = pybedtools.bedtool.BedTool.map(gene_window_bed, cage_bed, c=4, o='distinct', s=True)
out_df = out.to_dataframe()
out_df.columns=['chrom','gene_window_start','gene_window_end','gene','score','strand','peaks']
out_df = out_df[['chrom','gene_window_start','gene_window_end','gene','strand','peaks']]
out_df['peaks'] = out_df['peaks'].str.replace(',p',';p')

# %%
# Reformat matching results
peaks_per_gene_df = pd.merge(df_loc, out_df, on=['chrom','gene_window_start','gene_window_end','gene','strand'])
peaks_per_gene_df = peaks_per_gene_df[peaks_per_gene_df['peaks'] != '.']
peaks_per_gene_df['peaks'] = peaks_per_gene_df['peaks'].str.split(';')
peaks_per_gene_df['n_peaks'] = [len(peaks) for peaks in peaks_per_gene_df['peaks']]
peaks_per_gene_df
peaks_per_gene_df = peaks_per_gene_df[['gene', 'isTF', 'chrom', 'strand', 'txStart', 'txEnd', 'txLength',
                                       'gene_window_start', 'gene_window_end','peaks','n_peaks']]

# %%
# Visualize results
peaks_per_gene_df.head()
# Out:
#    gene   isTF  chrom strand    txStart      txEnd  txLength  \
# 0  ABI1  False  chr10      -   27035524   27150016    114492
# 1  ABI2  False   chr2      +  204193002  204296892    103890
# 2  ABI3  False  chr17      +   47287588   47300587     12999
# 3  ABL1  False   chr9      +  133589267  133763062    173795
# 4  ACTB  False   chr7      -    5566778    5570232      3454
#
#    gene_window_start  gene_window_end  \
# 0           27035524         27151016
# 1          204192002        204198002
# 2           47286588         47292588
# 3          133588267        133594267
# 4            5566778          5571232
#
#                                                peaks  n_peaks
# 0  [p1@ABI1, p2@ABI1, p3@ABI1, p4@ABI1, p@chr10:2...       10
# 1  [p1@ABI2, p2@ABI2, p3@ABI2, p4@ABI2, p5@ABI2, ...        6
# 2      [p1@ABI3, p2@ABI3, p3@ABI3, p4@ABI3, p5@ABI3]        5
# 3  [p@chr9:133588280..133588291,+, p@chr9:1335884...        3
# 4  [p10@ACTB, p11@ACTB, p12@ACTB, p13@ACTB, p14@A...       28

# %%
# Histogram of number of peaks per gene
plt.figure()
plt.hist(peaks_per_gene_df['n_peaks'], bins=np.arange(0,110,1))
plt.xlabel('number of peaks')
plt.ylabel('number of genes')
plt.title('histogram of number of peaks per gene')
plt.show()

# %% [markdown]
# # 3. Associate CAGE peaks with genes

# %%
# Dataframe of genes for each peak
genes_per_peak = peaks_per_gene_df[['gene','peaks']]
genes_per_peak = lu.unnesting(genes_per_peak,['peaks'])
genes_per_peak = genes_per_peak.groupby('peaks')['gene'].apply(list).reset_index(name='genes')
genes_per_peak['n_genes'] = [len(genes) for genes in genes_per_peak['genes']]
genes_per_peak.columns = ['short_description','genes','n_genes']
# Out:
# /home/louiscam/projects/gpcr/code/JASPAR_processing/utils.py:37: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   return df1.join(df.drop(explode, 1), how='left')

# %%
# Add peak location
genes_per_peak = pd.merge(genes_per_peak, cage_df, on=['short_description'])
genes_per_peak = genes_per_peak[['short_description','chrom','cage_start','cage_end','strand','genes']]
genes_per_peak = genes_per_peak.sort_values(by=['chrom'])

# %%
# Consider a window around each peak
genes_per_peak['cage_window_start'] = [genes_per_peak['cage_start'].iloc[i]-400 if (genes_per_peak['strand'].iloc[i]=='+') 
                                       else genes_per_peak['cage_start'].iloc[i]-50 for i in range(genes_per_peak.shape[0])]
genes_per_peak['cage_window_end'] = [genes_per_peak['cage_end'].iloc[i]+50 if (genes_per_peak['strand'].iloc[i]=='+') 
                                     else genes_per_peak['cage_end'].iloc[i]+400 for i in range(genes_per_peak.shape[0])]

# %%
# Visualize
genes_per_peak.head()
# Out:
#     short_description chrom  cage_start   cage_end strand      genes  \
# 757          p2@PYGO2  chr1   154936109  154936127      -     [SHC1]
# 795           p2@VAV3  chr1   108231101  108231133      -     [VAV3]
# 799     p2@uc001dqd.1  chr1    94240877   94240925      -    [BCAR3]
# 801       p30@ARHGEF2  chr1   155940369  155940382      -  [ARHGEF2]
# 830       p35@ARHGEF2  chr1   155942148  155942156      -  [ARHGEF2]
#
#      cage_window_start  cage_window_end
# 757          154936059        154936527
# 795          108231051        108231533
# 799           94240827         94241325
# 801          155940319        155940782
# 830          155942098        155942556

# %% [markdown]
# # 4. Create sequence files for all CAGE windows

# %% [raw]
# # Loop over all CAGE windows to generate sequence files
# for i in tqdm(range(genes_per_peak.shape[0])):
#     time.sleep(.01)
#     # Peak characteristics
#     peak = genes_per_peak['short_description'].iloc[i]
#     chrom = genes_per_peak['chrom'].iloc[i]
#     start = genes_per_peak['cage_window_start'].iloc[i]
#     end = genes_per_peak['cage_window_end'].iloc[i]
#     # Generate window sequence (sequence on the + strand)
#     result = subprocess.run(cage_fasta_dir+'twoBitToFa http://hgdownload.cse.ucsc.edu/gbdb/hg19/hg19.2bit '+
#                             cage_fasta_dir+peak+'.fa'+
#                             ' -seq='+chrom+' -start='+str(start)+' -end='+str(end)+' -noMask',
#                             shell=True)

# %% [markdown]
# # 5. Search for TFBS in all CAGE windows
# See process_JASPAR_with_strand.py

# %% [markdown]
# # 6. Find TFs binding each CAGE window

# %% [markdown]
# ### Useful data

# %%
# Load JASPAR TFBS metadata
jaspar_df = pd.read_csv(tf_dir+'JASPAR-HomoSapiens.csv', 
                        header=0, usecols=['ID','Name','Species','Class','Family'])
jaspar_tfs = np.unique(jaspar_df['Name'])
# Mapping JASPAR ID to HGNC
jasparid_to_hgnc = {jaspar_df.iloc[i,0]:jaspar_df.iloc[i,1] for i in range(jaspar_df.shape[0])}

# %%
# Visualize data
print('Number of unique TFs = '+str(len(np.unique(jaspar_df['Name']))))
print('Number of unique TF motifs = '+str(len(np.unique(jaspar_df['ID']))))
jaspar_df.head()
# Out:
# Number of unique TFs = 639
# Number of unique TF motifs = 810
#          ID    Name       Species                                  Class  \
# 0  MA0002.1   RUNX1  Homo sapiens                    Runt domain factors
# 1  MA0003.1  TFAP2A  Homo sapiens  Basic helix-span-helix factors (bHSH)
# 2  MA0003.2  TFAP2A  Homo sapiens  Basic helix-span-helix factors (bHSH)
# 3  MA0003.3  TFAP2A  Homo sapiens  Basic helix-span-helix factors (bHSH)
# 4  MA0003.4  TFAP2A  Homo sapiens  Basic helix-span-helix factors (bHSH)
#
#                  Family
# 0  Runt-related factors
# 1                  AP-2
# 2                  AP-2
# 3                  AP-2
# 4                  AP-2

# %% [markdown]
# ### Load MOODS results

# %%
# Create dictionary mapping CAGE peaks to the corresponding TFs
tfs_associated_to_cage_peaks = {}

# %% [raw]
# # Loop over files in moods_out_dir and summarize results
# for peak_moods_file in tqdm(os.listdir(moods_out_dir)):
#     time.sleep(.01)
#     # load results dataframe for that gene
#     cage_peak = peak_moods_file.strip('.txt')
#     res_df = pd.read_csv(moods_out_dir+peak_moods_file, sep=',', header=None,
#                          usecols=[0,1,2,3,4,5],
#                          names=['peak_id','tfbs_file','motif_loc','match_strand','match_score','motif'])
#     if (res_df.shape[0]>0):
#         # Add columns corresponding to the target peak
#         res_df['cage_peak'] = cage_peak
#         res_df['chrom'] = res_df['peak_id'].str.split(':', expand=True)[0]
#         location_cols = res_df['peak_id'].str.split(':', expand=True)[1]
#         res_df[['start','stop']] = location_cols.str.split('-', expand=True)
#         # Add columns corresponding to the TFBS
#         res_df['jaspar_tfbs'] = res_df['tfbs_file'].str.strip('.pfm')
#         res_df['TF'] = [jasparid_to_hgnc[jaspar_id] for jaspar_id in res_df['jaspar_tfbs']]
#         # Only keep TFs matching on the peak strand
#         peak_strand = cage_df[cage_df['short_description']==cage_peak]['strand'].values[0]
#         res_df = res_df[res_df['match_strand']==peak_strand]
#         # Select relevant columns
#         res_df = res_df[['cage_peak', 'chrom','start','stop','motif_loc',
#                          'jaspar_tfbs','TF','match_score','match_strand','motif']]
#         # Store list of TFs associated with the current CAGE peak in dict
#         tfs_associated_to_cage_peaks[cage_peak] = np.sort(np.unique(res_df['TF'].values))
# pickle.dump(tfs_associated_to_cage_peaks, open(saving_dir+'tfs_cage_with_strand.pkl', 'wb'))

# %% [markdown]
# # 7. Find TFs targeting genes of interest

# %%
# Load mapping between cage peaks and corresponding TFs
tfs_associated_to_cage_peaks = pickle.load(open(saving_dir+'tfs_cage_with_strand.pkl', 'rb'))

# %%
# Construct dataframe with gene-tf pairs
tf_and_genes_df = genes_per_peak.copy()
tf_and_genes_df['tfs'] = [tfs_associated_to_cage_peaks[cage_peak] if cage_peak in tfs_associated_to_cage_peaks.keys()
                          else ['missing']
                          for cage_peak in tf_and_genes_df['short_description'].values]
tf_and_genes_df = lu.unnesting(tf_and_genes_df,['genes'])
gene_to_tfs = {tf_and_genes_df.iloc[i,0]:tf_and_genes_df.iloc[i,8] for i in range(tf_and_genes_df.shape[0])}
tf_and_genes_df = lu.unnesting(tf_and_genes_df,['tfs'])
tf_and_genes_df = tf_and_genes_df[['genes','tfs','short_description','chrom','cage_start','cage_end','strand']]
tf_and_genes_df = tf_and_genes_df.sort_values(by=['genes','tfs'])
# Out:
# /home/louiscam/projects/gpcr/code/JASPAR_processing/utils.py:37: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   return df1.join(df.drop(explode, 1), how='left')

# %%
# Visualize results
tf_and_genes_df.head()
# Out:
#      genes    tfs             short_description  chrom  cage_start  cage_end  \
# 853   ABI1   ALX3                       p3@ABI1  chr10    27149904  27149920
# 853   ABI1  ARGFX                       p3@ABI1  chr10    27149904  27149920
# 1639  ABI1  BACH2  p@chr10:27149068..27149079,-  chr10    27149068  27149079
# 1637  ABI1   E2F6  p@chr10:27132379..27132382,-  chr10    27132379  27132382
# 1634  ABI1   EBF1  p@chr10:27037479..27037487,-  chr10    27037479  27037487
#
#      strand
# 853       -
# 853       -
# 1639      -
# 1637      -
# 1634      -

# %%
# Save dictionary mapping selected genes to their potential TFs to pickle
pickle.dump(gene_to_tfs, open(saving_dir+'gene_to_tfs_with_strand.pkl', 'wb'))
gene_to_tfs
# Out:
# {'SHC1': ['missing'],
#  'VAV3': array(['ESR1', 'ESR2', 'SMAD2::SMAD3::SMAD4'], dtype=object),
#  'BCAR3': ['missing'],
#  'ARHGEF2': array(['RREB1', 'ZBTB12'], dtype=object),
#  'ITGA10': array(['CTCF', 'CTCFL'], dtype=object),
#  'CSRP1': array(['ZNF263'], dtype=object),
#  'HAX1': array(['ZNF384'], dtype=object),
#  'FABP3': array(['EWSR1-FLI1', 'NR1I2', 'NR5A1', 'SPI1', 'ZKSCAN1', 'ZKSCAN5',
#         'ZNF354C'], dtype=object),
#  'FBLIM1': ['missing'],
#  'NEXN': array(['GRHL2', 'MAZ', 'NFATC4'], dtype=object),
#  'PTPRF': array(['ZNF740'], dtype=object),
#  'TSPAN1': array(['NFATC4', 'ZNF354C'], dtype=object),
#  'MACF1': ['missing'],
#  'ENAH': array(['ASCL1(var.2)', 'GLI2', 'GLI3', 'INSM1', 'NFKB1', 'TCF12(var.2)',
#         'TCF3', 'TCF4', 'TCF7L1', 'ZEB1', 'ZNF135', 'ZNF24', 'ZNF354C',
#         'ZNF460'], dtype=object),
#  'ARF1': array(['ATF6', 'KLF15', 'KLF5'], dtype=object),
#  'ASAP3': array(['ZNF341'], dtype=object),
#  'ITGB3BP': array(['EBF3', 'SPI1'], dtype=object),
#  'SLC9A1': array(['ESRRA', 'ESRRB', 'GRHL2', 'NR2F2', 'NR4A2', 'NR5A1', 'PKNOX1'],
#        dtype=object),
#  'CAPN2': ['missing'],
#  'RHOU': ['missing'],
#  'VIM': array(['FOS::JUN', 'FOS::JUNB', 'FOS::JUND', 'FOSL2::JUN', 'MZF1(var.2)',
#         'ZNF282'], dtype=object),
#  'ITGA8': array(['CDX2', 'ZNF384'], dtype=object),
#  'NRP1': array(['RBPJ', 'STAT1'], dtype=object),
#  'LDB3': array(['EBF1', 'EBF3', 'FOS', 'FOS::JUN', 'FOS::JUNB', 'FOS::JUND',
#         'FOSB::JUNB', 'FOSL2::JUN', 'FOSL2::JUNB', 'SPIB', 'STAT1::STAT2'],
#        dtype=object),
#  'PTEN': array(['TFAP2B(var.2)'], dtype=object),
#  'ADAM12': array(['EHF', 'ELF3', 'EWSR1-FLI1', 'GABPA', 'PAX1', 'PAX9', 'RFX2',
#         'RFX4', 'RFX5'], dtype=object),
#  'ITGB1': array(['EHF', 'ELF3', 'GABPA', 'PRDM4', 'SPI1', 'SPIB'], dtype=object),
#  'SVIL': ['missing'],
#  'SORBS1': array(['HOXB13', 'MAFF', 'MYBL1', 'NR2F1', 'NR2F2', 'NR4A1', 'OTX2',
#         'RORA', 'TFE3', 'TFEC', 'ZNF317'], dtype=object),
#  'VCL': array(['SMAD2::SMAD3::SMAD4', 'SRF', 'ZNF143', 'ZNF682'], dtype=object),
#  'ABI1': array(['MAZ', 'RREB1', 'THAP11', 'ZNF148', 'ZNF263', 'ZNF384', 'ZNF410'],
#        dtype=object),
#  'MAPK8': ['missing'],
#  'DOCK1': array(['NFATC2', 'NFATC4', 'RELA', 'SPI1', 'YY1', 'ZFP42'], dtype=object),
#  'THY1': array(['IKZF1', 'MAFK', 'MAZ', 'ZNF148'], dtype=object),
#  'PARVA': array(['EWSR1-FLI1', 'NR2C2'], dtype=object),
#  'ARHGEF12': array(['CDX1', 'CDX2', 'CDX4', 'HOXA10', 'HOXD9', 'IRF3', 'IRF9'],
#        dtype=object),
#  'RDX': array(['CTCF', 'NFATC3', 'STAT1::STAT2'], dtype=object),
#  'LAYN': array(['PPARG'], dtype=object),
#  'PAK1': array(['IRF2', 'NFATC2', 'SPI1'], dtype=object),
#  'ILK': array(['RFX1'], dtype=object),
#  'CAPN1': array(['EHF', 'GATA3', 'MAZ', 'POU6F1', 'RREB1', 'ZBTB7B', 'ZNF148'],
#        dtype=object),
#  'ARHGAP32': array(['ELF1', 'ELF5', 'ETV1', 'ETV4', 'GBX2', 'SMAD2::SMAD3::SMAD4',
#         'ZBTB7A'], dtype=object),
#  'CBL': array(['CTCF', 'IRF3', 'KLF5', 'ZNF136'], dtype=object),
#  'CD151': array([], dtype=object),
#  'CFL1': array(['RREB1', 'SP3', 'SP8', 'SP9'], dtype=object),
#  'CORO1B': array(['EHF', 'ELF3', 'GABPA', 'KLF15', 'KLF5', 'SP2', 'SPIB'],
#        dtype=object),
#  'INPPL1': array(['FOXF2', 'MYF5', 'SMAD2::SMAD3::SMAD4'], dtype=object),
#  'LPXN': array(['ELF1', 'ETV6', 'SMAD2::SMAD3::SMAD4', 'SPI1', 'ZNF140'],
#        dtype=object),
#  'CTTN': array(['EGR1', 'ELF2', 'ELF4', 'ELF5', 'ELK1', 'ELK3', 'ERF', 'ERG',
#         'ETS1', 'ETS2', 'ETV1', 'ETV2', 'ETV3', 'FEV', 'FLI1', 'HES2',
#         'IRF4', 'IRF8', 'KLF15', 'KLF5', 'SPDEF', 'SPIC'], dtype=object),
#  'HRAS': array(['ZNF449', 'ZNF460'], dtype=object),
#  'FERMT3': array(['E2F7', 'EWSR1-FLI1', 'ZBTB12', 'ZNF136'], dtype=object),
#  'SLC3A2': array([], dtype=object),
#  'PPFIA1': array(['EOMES', 'GFI1', 'KLF15', 'KLF5', 'NFYA', 'NFYC', 'TBR1', 'TBX2',
#         'TBX21', 'TBX6'], dtype=object),
#  'PTPRO': array(['ZSCAN4'], dtype=object),
#  'ITGA7': ['missing'],
#  'TUBA1B': array(['HIC2', 'IRF3', 'KLF15', 'KLF5', 'MYC', 'SP1', 'SP4', 'ZNF24'],
#        dtype=object),
#  'SSH1': array(['KLF4', 'NFATC2', 'NR1H2::RXRA', 'NR2F1(var.2)', 'NR2F2', 'NR4A1',
#         'PPARA::RXRA', 'RREB1', 'ZNF740'], dtype=object),
#  'TENC1': array(['MYOG', 'NR4A2::RXRA', 'POU1F1', 'POU2F3', 'POU5F1B', 'REST',
#         'ZNF354C', 'ZNF528'], dtype=object),
#  'ITGA5': array(['MZF1(var.2)', 'NFIC(var.2)', 'NFIX(var.2)', 'ZNF740'],
#        dtype=object),
#  'LRP1': array(['BCL6B', 'NR2C2', 'NRF1', 'ZNF263'], dtype=object),
#  'PXN': ['missing'],
#  'AGAP2': array([], dtype=object),
#  'PTPN6': array(['GABPA', 'TBX19', 'TBXT'], dtype=object),
#  'PTPN11': array(['ATF3', 'CREM', 'ELF1', 'ETV1', 'ETV4', 'FOSL2::JUN(var.2)',
#         'FOSL2::JUND(var.2)', 'HOXD3', 'IKZF1', 'ONECUT2', 'ONECUT3',
#         'ZKSCAN1'], dtype=object),
#  'GIT2': array(['BHLHE22(var.2)', 'FERD3L', 'MITF', 'TFAP2A', 'YY1'], dtype=object),
#  'ITGB7': array(['EHF', 'ELF3', 'KLF4', 'KLF5', 'RREB1', 'SP2', 'SPIB', 'ZNF682'],
#        dtype=object),
#  'STARD13': array(['NRL'], dtype=object),
#  'ARHGEF7': array(['ATF2', 'ATF3', 'ATF7', 'CDX2', 'CREB1', 'CREM', 'FOSB::JUN',
#         'FOSB::JUNB(var.2)', 'FOSL1::JUN(var.2)', 'FOSL2::JUN(var.2)',
#         'FOSL2::JUNB(var.2)', 'FOSL2::JUND(var.2)', 'FOXC1', 'FOXC2',
#         'FOXD2', 'FOXE1', 'FOXF2', 'FOXG1', 'FOXK1', 'FOXK2', 'FOXN3',
#         'FOXO3', 'FOXO6', 'FOXP1', 'HOXB13', 'IRF1', 'JUN',
#         'JUN::JUNB(var.2)', 'JUND(var.2)', 'MEF2A', 'MEF2C', 'SOX10',
#         'SOX4', 'SPIB', 'SRY', 'STAT1', 'STAT1::STAT2', 'STAT3', 'ZNF384'],
#        dtype=object),
#  'MMP14': array(['BCL6B', 'IRF1', 'NR1D1'], dtype=object),
#  'FERMT2': array(['BHLHA15(var.2)', 'FOXN3', 'ZNF140'], dtype=object),
#  'ACTN1': array(['LEF1', 'NR5A1', 'ZNF354C'], dtype=object),
#  'ZFYVE21': array(['NFYA', 'NFYC', 'PBX1', 'VENTX'], dtype=object),
#  'HSPA2': array(['FOXN3', 'NFYB', 'POU2F2'], dtype=object),
#  'KTN1': array(['ARNT::HIF1A', 'KLF5'], dtype=object),
#  'ARHGAP5': array(['MAZ', 'ZNF148'], dtype=object),
#  'AKT1': array(['MYBL1'], dtype=object),
#  'SYNM': array(['CTCFL', 'MEF2A', 'MEF2B', 'MEF2C', 'MEF2D', 'NFATC3',
#         'STAT1::STAT2', 'THAP1', 'ZNF354C'], dtype=object),
#  'ITGA11': array(['ELF3', 'GABPA', 'IRF3', 'MAZ', 'SPIB', 'ZNF354C'], dtype=object),
#  'CSK': array(['CTCF', 'CTCFL', 'KLF10', 'POU4F1', 'ZIC3', 'ZIC4', 'ZIC5'],
#        dtype=object),
#  'PEAK1': array(['EWSR1-FLI1', 'KLF5', 'NFYA', 'NFYC', 'SP1', 'SP2', 'SP4'],
#        dtype=object),
#  'TRPM7': array(['BCL6B', 'MLX', 'MLXIPL', 'NFIL3', 'STAT1', 'TFE3'], dtype=object),
#  'CIB2': array(['E2F6', 'ELF3', 'ELK4', 'ETV5', 'NR2C2', 'NR2F1(var.2)', 'PPARD',
#         'RXRB', 'RXRG', 'TFDP1', 'THRB', 'ZNF354C'], dtype=object),
#  'CIB1': array(['NR2C2(var.2)', 'RARA(var.2)', 'RARA::RXRG', 'RARB(var.3)',
#         'RXRB(var.2)', 'RXRG(var.2)', 'SNAI3', 'SOX21'], dtype=object),
#  'BCAR1': array(['BCL6B', 'SREBF2', 'TFAP2C(var.2)'], dtype=object),
#  'MAPK8IP3': array(['ATF3', 'ATF7', 'CREB1', 'CREB3L4(var.2)', 'CREM', 'ELK4', 'ETS2',
#         'ETV5', 'FOSB::JUN', 'FOSB::JUNB(var.2)', 'FOSL1::JUN(var.2)',
#         'FOSL2::JUNB(var.2)', 'FOSL2::JUND(var.2)', 'JDP2(var.2)',
#         'JUN::JUNB(var.2)', 'JUNB(var.2)', 'MYOG', 'NHLH1', 'NR2C1',
#         'NR4A2', 'PBX3', 'PKNOX1', 'RORA', 'RORB', 'SIX1'], dtype=object),
#  'TGFB1I1': array([], dtype=object),
#  'PDPK1': ['missing'],
#  'ITGAL': array(['ELF1', 'ETV1', 'HNF4A(var.2)', 'IKZF1', 'NR1H2::RXRA',
#         'NR2F1(var.2)', 'PLAG1', 'PPARA::RXRA', 'PPARD', 'RXRB', 'RXRG',
#         'THRB'], dtype=object),
#  'ITGAX': array(['ESRRA', 'ESRRB', 'FOS', 'NR2F1', 'NR2F1(var.2)', 'NR2F2', 'NR5A1',
#         'NR6A1', 'RORA', 'SPDEF', 'THRB'], dtype=object),
#  'SH2B1': ['missing'],
#  'PKD1': array(['ATF2', 'ATF3', 'CREB1', 'FOSB::JUN', 'FOSL2::JUN(var.2)',
#         'FOSL2::JUNB(var.2)', 'JDP2(var.2)', 'JUN', 'JUNB(var.2)',
#         'JUND(var.2)'], dtype=object),
#  'ITGAM': array(['ARGFX', 'EWSR1-FLI1', 'ISX', 'LHX9', 'MEF2A', 'MIXL1', 'MNX1',
#         'NKX6-2', 'POU6F2', 'PRRX1', 'PRRX2', 'RAX', 'UNCX', 'ZNF135',
#         'ZNF263', 'ZNF460'], dtype=object),
#  'NUDT16L1': array(['MTF1', 'NFIA', 'RUNX2', 'ZBTB6'], dtype=object),
#  'ITGAD': array(['EWSR1-FLI1', 'KLF13', 'POU4F2', 'POU4F3', 'SP1', 'SP4', 'SP9',
#         'ZNF354C'], dtype=object),
#  'SRCIN1': array(['CDX4', 'HOXA13', 'HOXC13'], dtype=object),
#  'STAT3': array(['BACH2(var.2)', 'MAX', 'MAX::MYC', 'POU4F1', 'POU4F3', 'PRDM1',
#         'ZNF341'], dtype=object),
#  'GIT1': array(['BACH2', 'BATF', 'BATF3', 'BATF::JUN', 'ELF3', 'FOS', 'FOS::JUN',
#         'FOS::JUNB', 'FOSB::JUNB', 'FOSL1', 'FOSL1::JUN', 'FOSL1::JUNB',
#         'FOSL1::JUND', 'FOSL2', 'FOSL2::JUN', 'FOSL2::JUNB', 'FOSL2::JUND',
#         'GSC', 'GSC2', 'IRF2', 'IRF7', 'JDP2', 'JUN(var.2)', 'JUN::JUNB',
#         'JUNB', 'JUND', 'MZF1', 'NFE2', 'OTX1', 'PITX1', 'PITX2', 'PITX3',
#         'PRDM1'], dtype=object),
#  'ITGB4': array(['BACH1', 'BATF', 'BATF3', 'BATF::JUN', 'CDX4', 'FOS', 'FOS::JUNB',
#         'FOSB::JUNB', 'FOSL1', 'FOSL1::JUN', 'HOXA13', 'HOXD13', 'JUNB',
#         'JUND', 'MAFK', 'SNAI3'], dtype=object),
#  'PRKCA': array(['ETV4', 'MZF1', 'SOX9', 'SPI1', 'ZNF384'], dtype=object),
#  'PFN1': array(['ELF1', 'ELF5', 'ETV1', 'ETV4', 'HOXB13', 'IKZF1', 'KLF15', 'KLF5',
#         'SP1', 'SP2', 'SP4', 'SPI1', 'ZBTB7A', 'ZNF263'], dtype=object),
#  'NDEL1': array(['ATF6', 'KLF15', 'KLF16', 'KLF4', 'KLF5', 'NR1I3', 'NRF1'],
#        dtype=object),
#  'GRB2': array(['EWSR1-FLI1', 'NFYB', 'PKNOX2', 'SPI1', 'SPIC', 'TGIF2'],
#        dtype=object),
#  'GRB7': array(['SP4', 'SRY'], dtype=object),
#  'ITGA3': array(['IRF1', 'STAT1::STAT2'], dtype=object),
#  'CRK': array(['MYB', 'NEUROD1', 'NEUROG2(var.2)', 'NFATC2', 'NR2C1', 'NRL',
#         'TGIF1'], dtype=object),
#  'ITGAE': array(['ASCL1', 'FERD3L', 'MYOG', 'SP2', 'ZSCAN4'], dtype=object),
#  'ABI3': array(['EHF', 'EWSR1-FLI1', 'GFI1', 'GRHL2', 'IRF2', 'NFATC4', 'SPIB',
#         'ZNF354C'], dtype=object),
#  'SLC16A3': array(['GRHL2', 'NFATC3', 'POU1F1'], dtype=object),
#  'ITGB3': array(['EOMES', 'MAZ', 'NRL', 'PAX3', 'PAX7', 'PPARG', 'PROP1', 'TBR1',
#         'TBX2', 'TBX21', 'ZNF148'], dtype=object),
#  'LASP1': array(['TWIST1', 'ZBTB18', 'ZNF75D'], dtype=object),
#  'PTPN2': array(['ARNT::HIF1A', 'EWSR1-FLI1'], dtype=object),
#  'MYOM1': array(['ARNT::HIF1A', 'ZBTB14', 'ZNF460'], dtype=object),
#  'ROCK1': array(['ASCL1', 'ETV1', 'ETV4', 'IKZF1', 'KLF4', 'KLF5', 'MYOG', 'SP1',
#         'SP4', 'SPI1', 'THAP1'], dtype=object),
#  'INSR': array(['FOXA1', 'FOXB1', 'FOXC1', 'FOXC2', 'FOXD2', 'FOXE1', 'FOXF2',
#         'IRF3', 'IRF4', 'IRF9', 'ZNF384'], dtype=object),
#  'CALR': array(['INSM1', 'MEIS1', 'RXRB', 'STAT1::STAT2'], dtype=object),
#  'PLAUR': array(['E2F6', 'MEF2A', 'MEF2D', 'RUNX3', 'RXRB(var.2)', 'RXRG(var.2)',
#         'ZBTB12'], dtype=object),
#  'PRKACA': array(['GLIS3', 'IRF1', 'STAT1::STAT2'], dtype=object),
#  'DNM2': array(['CEBPA', 'CEBPD', 'EBF1', 'MEIS1', 'MZF1', 'PBX3', 'PKNOX1',
#         'SPIB'], dtype=object),
#  'KEAP1': array(['FOS', 'GLIS3', 'MZF1', 'ZBTB12'], dtype=object),
#  'PVR': array(['IKZF1', 'NFKB2', 'TFDP1'], dtype=object),
#  'VASP': array(['MEIS1', 'ZBTB7B', 'ZNF143'], dtype=object),
#  'CYTH2': array(['SP1', 'SP2', 'SP4', 'ZNF263'], dtype=object),
#  'PTPRH': array(['EHF', 'ELF3', 'GABPA', 'IRF1', 'PRDM1', 'SPIB'], dtype=object),
#  'VAV1': array(['ELF1', 'RREB1', 'SPI1'], dtype=object),
#  'PIP5K1C': array(['FOS::JUN', 'FOS::JUND', 'FOSL2::JUN', 'HES7', 'KLF15', 'KLF16',
#         'KLF5', 'NFE2', 'SOX21', 'SP1', 'SP4'], dtype=object),
#  'RAVER1': array(['E2F6', 'GATA1', 'HOXA13', 'HOXB13', 'OSR2', 'TFDP1', 'YY1', 'YY2',
#         'ZFP42', 'ZNF354C', 'ZSCAN29'], dtype=object),
#  'TNS1': array(['SOHLH2'], dtype=object),
#  'SOS1': array(['ASCL1', 'MYOG', 'THAP11'], dtype=object),
#  'LIMS2': array(['ASCL1', 'BHLHE22(var.2)', 'IRF1', 'NHLH1', 'NR5A1', 'PRDM1',
#         'ZNF354C'], dtype=object),
#  'FHL2': array(['LEF1', 'TCF7L1', 'TCF7L2', 'ZNF384'], dtype=object),
#  'IRS1': array(['CTCF', 'EBF1'], dtype=object),
#  'INPP5D': array(['ELF1', 'ETV1', 'ETV4', 'IKZF1', 'IRF1', 'POU6F1(var.2)', 'PRDM1',
#         'SPI1', 'SPIC', 'STAT1::STAT2', 'TBXT'], dtype=object),
#  'ITGA4': array(['GATA1::TAL1', 'GATA6', 'HES6', 'SOHLH2'], dtype=object),
#  'NRP2': array(['LMX1B', 'PAX6', 'SPI1'], dtype=object),
#  'ITGA6': array(['FIGLA', 'FOXE1', 'HNF1A'], dtype=object),
#  'ITGAV': array(['EHF', 'ELF3', 'ELF5', 'EWSR1-FLI1', 'SPIB'], dtype=object),
#  'ITGB6': ['missing'],
#  'ITGB1BP1': array(['MAX::MYC', 'MSANTD3', 'NR2F1(var.3)', 'PKNOX2', 'TGIF2',
#         'THRB(var.2)', 'ZNF317'], dtype=object),
#  'ASAP2': array(['KLF5', 'SOX13', 'SOX18', 'SOX2', 'SOX4', 'SOX8', 'SRY'],
#        dtype=object),
#  'ARPC2': array(['ETV6'], dtype=object),
#  'LIMS1': ['missing'],
#  'ILKAP': array(['FOXC1', 'ZNF384'], dtype=object),
#  'NCK2': ['missing'],
#  'ABI2': array(['ELF1', 'ELF4', 'ELK1', 'ELK3', 'ERF', 'ERG', 'ETS1', 'ETV1',
#         'ETV3', 'ETV4', 'ETV6', 'EWSR1-FLI1', 'FEV', 'FLI1', 'HSF4',
#         'KLF15', 'KLF5', 'MYBL1', 'PRDM4', 'SOX10', 'SOX4', 'SOX8', 'SRY',
#         'ZBTB7A', 'ZNF652'], dtype=object),
#  'CASP8': ['missing'],
#  'SDC4': array(['ASCL1(var.2)', 'MEF2B', 'MEF2D', 'NHLH1', 'TCF12(var.2)', 'TCF4',
#         'ZNF341'], dtype=object),
#  'FERMT1': array(['SPI1'], dtype=object),
#  'SIRPA': array(['FOXC1', 'FOXC2', 'FOXD2', 'FOXE1', 'GRHL1', 'GRHL2', 'ZNF652'],
#        dtype=object),
#  'PLCG1': array(['EGR1', 'HNF4A', 'HNF4G', 'KLF15', 'KLF5', 'PROP1'], dtype=object),
#  'PTPN1': array(['BATF', 'BATF3', 'BATF::JUN', 'ETV6', 'MSANTD3', 'NR1I2', 'RFX5',
#         'SPIB'], dtype=object),
#  'PRNP': array(['NR3C2'], dtype=object),
#  'CASS4': array(['EWSR1-FLI1', 'NR1H2::RXRA', 'PBX3', 'PKNOX1', 'RXRB', 'TCF7L1',
#         'TCF7L2'], dtype=object),
#  'SRC': ['missing'],
#  'PTPRA': ['missing'],
#  'ITGB2': array(['ELF1', 'ELF3', 'ELF5', 'ERF', 'ETV1', 'ETV2', 'ETV4', 'IKZF1',
#         'NR2C2', 'OSR1', 'SPI1', 'TBR1'], dtype=object),
#  'TIAM1': array(['E2F8', 'NFATC2', 'PRDM1'], dtype=object),
#  'MYH9': array(['RARA::RXRA'], dtype=object),
#  'NF2': array(['NFATC3', 'NKX2-2', 'NKX2-5', 'THRB(var.2)'], dtype=object),
#  'CRKL': array(['ATF3', 'ATF7', 'DBP', 'FOSB::JUN', 'FOSB::JUNB(var.2)',
#         'FOSL1::JUN(var.2)', 'FOSL1::JUND(var.2)', 'FOSL2::JUN(var.2)',
#         'FOSL2::JUNB(var.2)', 'GMEB2', 'GRHL2', 'MZF1(var.2)', 'OSR2',
#         'TEF', 'TFAP2A'], dtype=object),
#  'PPM1F': array(['FOXC1', 'FOXC2', 'GABPA', 'MEF2A', 'MEF2B', 'MEF2C', 'MEF2D',
#         'MEIS1', 'MYF5', 'ONECUT1', 'SOX21', 'SPIB'], dtype=object),
#  'MAPK1': array(['EWSR1-FLI1', 'KLF15', 'KLF5', 'YY1', 'YY2', 'ZFP42'], dtype=object),
#  'RNF185': array(['MITF', 'NR2C2', 'THAP1', 'USF1', 'USF2', 'ZBTB7A', 'ZNF135',
#         'ZNF460'], dtype=object),
#  'ANKRD28': array(['GLIS2', 'RFX2', 'RFX4', 'RFX5'], dtype=object),
#  'CD47': array(['ETV6', 'NEUROG1', 'NEUROG2', 'NFATC2', 'NFATC4', 'OTX2', 'TGIF1',
#         'TGIF2', 'TGIF2LX', 'TGIF2LY'], dtype=object),
#  'LPP': ['missing'],
#  'PLD1': array(['PKNOX1', 'ZNF354C'], dtype=object),
#  'PPM1M': array(['PBX3', 'PKNOX1', 'ZKSCAN5'], dtype=object),
#  'ITGB5': array(['KLF5', 'SPI1', 'ZNF460'], dtype=object),
#  'RHOA': array(['SNAI2'], dtype=object),
#  'NISCH': array(['CEBPG', 'DBP', 'HLF', 'IRF1', 'IRF7', 'NR4A2::RXRA', 'SP1', 'SP4',
#         'SP8', 'SP9', 'YY1', 'YY2', 'ZFP42'], dtype=object),
#  'PIK3CA': array(['FOXN3', 'HOXA13', 'HOXB13', 'IRF1', 'SPIB', 'ZNF384'],
#        dtype=object),
#  'ITGA9': array(['CTCF', 'GATA1', 'GATA2', 'GATA4', 'GATA6', 'IRF3', 'SOX10'],
#        dtype=object),
#  'SORBS2': array(['GATA3', 'MEF2C', 'NFYB', 'TFAP2A(var.3)', 'TFAP2B(var.3)',
#         'TFAP2C(var.3)'], dtype=object),
#  'GAB1': array(['OSR2'], dtype=object),
#  'PALLD': array(['SIX2'], dtype=object),
#  'ARHGAP24': array(['NKX2-8', 'SIX2'], dtype=object),
#  'PDE4D': array(['FOXC2', 'FOXE1', 'KLF14'], dtype=object),
#  'ARHGAP26': array(['DUX4', 'FOXC2', 'FOXE1'], dtype=object),
#  'GNB2L1': array(['ATF4', 'CEBPG(var.2)', 'MZF1', 'NEUROD1', 'NEUROG2(var.2)',
#         'PKNOX2', 'TGIF1', 'TGIF2'], dtype=object),
#  'ITGA1': array(['TBX18', 'TBX20'], dtype=object),
#  'RASA1': array(['EMX1', 'EMX2', 'EN1', 'HOXB3', 'KLF4', 'KLF5', 'MEIS1', 'MSGN1',
#         'NEUROD2', 'NOTO', 'PAX4', 'SREBF2', 'TCF21(var.2)', 'TLX2',
#         'VSX2', 'ZNF135', 'ZNF460'], dtype=object),
#  'TRIO': ['missing'],
#  'ITGA2': array(['HIC2', 'MZF1'], dtype=object),
#  'EZR': array(['HOXC4', 'SPIB', 'ZNF354C'], dtype=object),
#  'MARCKS': array(['KLF14', 'KLF15', 'KLF16', 'LMX1A', 'LMX1B', 'MAZ', 'MEIS2(var.2)',
#         'PAX3', 'SOX9', 'SP1', 'SP3', 'SP4', 'SP8', 'SP9', 'ZNF148'],
#        dtype=object),
#  'FYN': array(['HNF4A(var.2)', 'SNAI1', 'SNAI3', 'TFAP2A(var.3)', 'TFAP2B(var.3)',
#         'TFAP2C(var.3)'], dtype=object),
#  'NEDD9': ['missing'],
#  'DEF6': array(['SIX2', 'TFCP2', 'ZBTB26', 'ZNF16'], dtype=object),
#  'KCNH2': array(['MAFK', 'MEIS1(var.2)', 'NKX6-3', 'PBX2'], dtype=object),
#  'ITGB8': array(['RARA'], dtype=object),
#  'ACTB': array(['ZNF354C'], dtype=object),
#  'RAC1': array(['BCL6B', 'E2F3', 'EHF', 'ELF3', 'GABPA', 'IRF1', 'KLF2', 'KLF3',
#         'KLF6', 'NFATC2', 'PRDM4', 'SPIB', 'YY1', 'ZFP42'], dtype=object),
#  'HSPB1': array(['FOXC2', 'FOXN3', 'HSF1', 'HSF2', 'HSF4', 'NFIB', 'NFIC(var.2)',
#         'NFIX(var.2)', 'ZNF384'], dtype=object),
#  'TES': array(['HOXB13', 'NFATC4'], dtype=object),
#  'LIMK1': array(['EWSR1-FLI1', 'KLF15', 'KLF5', 'ONECUT1', 'POU4F1', 'POU4F2',
#         'POU4F3'], dtype=object),
#  'PTPN12': array(['SOX15', 'SOX9', 'ZBTB7B'], dtype=object),
#  'TRIP6': array(['SPI1'], dtype=object),
#  'PLEC': array(['ATF2', 'CREB1', 'JUN'], dtype=object),
#  'LYN': array(['ELF1', 'ELF5', 'POU1F1', 'POU2F1', 'POU2F3', 'POU3F1', 'POU3F2',
#         'POU3F3', 'POU3F4', 'POU5F1', 'POU5F1B', 'PRDM1', 'RARA', 'SPIB'],
#        dtype=object),
#  'PABPC1': array(['ELF2', 'ELF4', 'ELF5', 'EWSR1-FLI1', 'IRF1', 'KLF5', 'NRF1',
#         'SP2', 'SP4', 'SPIB'], dtype=object),
#  'SHARPIN': array(['SMAD2::SMAD3::SMAD4', 'ZNF460'], dtype=object),
#  'DLC1': array(['ARGFX', 'ISX', 'LHX9', 'NKX6-2', 'PRRX1', 'PRRX2', 'UNCX'],
#        dtype=object),
#  'PTK2': array(['FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3', 'NFATC2', 'PRDM1',
#         'ZBTB26'], dtype=object),
#  'SORBS3': array(['IRF3', 'IRF4', 'IRF5', 'IRF8', 'SIX1', 'STAT3'], dtype=object),
#  'PTK2B': ['missing'],
#  'SDCBP': array(['RFX2', 'RFX5', 'SREBF1', 'TCF7'], dtype=object),
#  'TLN1': array(['IKZF1', 'MEF2C', 'POU1F1', 'POU2F1', 'POU2F3', 'POU3F1', 'POU3F2',
#         'POU3F3', 'POU3F4', 'POU5F1', 'POU5F1B', 'SPI1'], dtype=object),
#  'RAPGEF1': array(['ASCL1', 'EWSR1-FLI1', 'MYOG', 'NFIC'], dtype=object),
#  'ABL1': array(['MEIS1(var.2)', 'THAP11', 'ZFP42'], dtype=object),
#  'VAV2': array(['ELF1', 'ETV1', 'ETV4', 'HNF4A', 'HNF4G', 'HOXA9', 'KLF5', 'SP2'],
#        dtype=object),
#  'ENG': ['missing'],
#  'TESK1': array(['ATF3', 'FOS::JUN(var.2)', 'FOSL2::JUNB(var.2)',
#         'FOSL2::JUND(var.2)', 'JDP2(var.2)'], dtype=object),
#  'OSTF1': array(['ELF1', 'ETV1', 'HOXC4', 'NR1D1', 'NR1D2', 'PAX5', 'RXRB(var.2)',
#         'RXRG(var.2)', 'ZNF384'], dtype=object),
#  'SPTLC1': array(['ESR1', 'ESR2', 'FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3',
#         'GSX2', 'HOXA2', 'HOXB2', 'IRF4', 'IRF8', 'MSANTD3', 'NFIL3',
#         'PDX1', 'PPARG', 'ZNF528'], dtype=object),
#  'CORO2A': array(['FOXE1', 'NFATC2', 'NKX2-8', 'NR2F1(var.3)', 'THRB(var.3)',
#         'ZBTB12', 'ZNF135', 'ZNF460'], dtype=object)}

# %%
tf_and_genes_df[tf_and_genes_df['genes']=='PDPK1']
# Out:
#       genes      tfs           short_description  chrom  cage_start  cage_end  \
# 430   PDPK1  missing                    p1@PDPK1  chr16     2588012   2588031
# 736   PDPK1  missing                    p2@PDPK1  chr16     2587980   2587994
# 952   PDPK1  missing                    p3@PDPK1  chr16     2587999   2588011
# 1123  PDPK1  missing                    p4@PDPK1  chr16     2588131   2588143
# 1876  PDPK1  missing  p@chr16:2589098..2589102,+  chr16     2589098   2589102
#
#      strand
# 430       +
# 736       +
# 952       +
# 1123      +
# 1876      +
