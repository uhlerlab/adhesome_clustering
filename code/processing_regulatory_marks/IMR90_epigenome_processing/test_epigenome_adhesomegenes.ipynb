# %%
from importlib import reload
import sys
import numpy as np 
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
plt.ioff()
import seaborn as sns
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
import pybedtools
from joblib import Parallel, delayed
import get_feature_matrix_adhesomegenes as gfma
import utils as lu
from tqdm import tqdm
import time
import pickle
import pybedtools
# Out:
# /home/louiscam/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Reload modules in case of modifications
reload(lu)
reload(gfma)
# Out:
# <module 'get_feature_matrix_adhesomegenes' from '/home/louiscam/projects/gpcr/code/epigenome_processing/get_feature_matrix_adhesomegenes.py'>

# %% [markdown]
# # Data directories

# %%
genome_dir = '/home/louiscam/projects/gpcr/data/genome_data/'
epigenome_dir = '/home/louiscam/projects/gpcr/data/epigenome_data_targetfinder/'
processed_epigenome_data_dir = '/home/louiscam/projects/gpcr/save/processed_epigenome_data_dir/'
dir_adhesome = '/home/louiscam/projects/gpcr/data/adhesome_data/'
saving_dir = '/home/louiscam/projects/gpcr/save/figures/'

# %%
cell_type = 'IMR90'
resol_str = '250kb'
resol = 250000
quality = 'MAPQGE30'

# %%
# Load functional genomic data ids
func_gen_table = pd.read_csv(epigenome_dir+'filenames_belyaeva.csv', sep=',', header=0)
func_gen_table
# Out:
#          name                                           filename  \
# 0      RNAseq  GSM438363_UCSD.IMR90.mRNA-Seq.mRNA-seq_imr90_r...
# 1       CEBPB  wgEncodeAwgTfbsSydhImr90CebpbIggrabUniPk.narro...
# 2        CHD1  wgEncodeSydhTfbsImr90Chd1nb10060411IggrabPk.na...
# 3        CTCF  wgEncodeAwgTfbsSydhImr90CtcfbIggrabUniPk.narro...
# 4   DNase-seq                        E017-DNase.macs2.narrowPeak
# 5       EP300                        EP300-LICR_peaks.narrowPeak
# 6     H2AK5ac                            E017-H2AK5ac.narrowPeak
# 7     H2AK9ac                            E017-H2AK9ac.narrowPeak
# 8        H2AY                         H2AY-Chen_peaks.narrowPeak
# 9        H2AZ                              E017-H2A.Z.narrowPeak
# 10  H2BK120ac                          E017-H2BK120ac.narrowPeak
# 11   H2BK12ac                           E017-H2BK12ac.narrowPeak
# 12   H2BK15ac                           E017-H2BK15ac.narrowPeak
# 13   H2BK20ac                           E017-H2BK20ac.narrowPeak
# 14    H2BK5ac                            E017-H2BK5ac.narrowPeak
# 15    H3K14ac                            E017-H3K14ac.narrowPeak
# 16    H3K18ac                            E017-H3K18ac.narrowPeak
# 17    H3K23ac                            E017-H3K23ac.narrowPeak
# 18    H3K27ac                            E017-H3K27ac.narrowPeak
# 19   H3K27me3                           E017-H3K27me3.narrowPeak
# 20   H3K36me3                           E017-H3K36me3.narrowPeak
# 21     H3K4ac                             E017-H3K4ac.narrowPeak
# 22    H3K4me1                            E017-H3K4me1.narrowPeak
# 23    H3K4me2                            E017-H3K4me2.narrowPeak
# 24    H3K4me3                            E017-H3K4me3.narrowPeak
# 25    H3K56ac                            E017-H3K56ac.narrowPeak
# 26   H3K79me1                           E017-H3K79me1.narrowPeak
# 27   H3K79me2                           E017-H3K79me2.narrowPeak
# 28     H3K9ac                             E017-H3K9ac.narrowPeak
# 29    H3k9me1                            E017-H3K9me1.narrowPeak
# 30    H3K9me3                            E017-H3K9me3.narrowPeak
# 31   H4K20me1                           E017-H4K20me1.narrowPeak
# 32     H4K5ac                             E017-H4K5ac.narrowPeak
# 33     H4K8ac                             E017-H4K8ac.narrowPeak
# 34    H4K91ac                            E017-H4K91ac.narrowPeak
# 35      LMNB1                        LMNB1-Otte_peaks.narrowPeak
# 36       MAFK  wgEncodeAwgTfbsSydhImr90MafkIggrabUniPk.narrow...
# 37        MAZ  wgEncodeSydhTfbsImr90Mazab85725IggrabPk.narrow...
# 38      MECP2                    MECP2-Maunakea_peaks.narrowPeak
# 39       MXI1       wgEncodeSydhTfbsImr90Mxi1IggrabPk.narrowPeak
# 40     POLR2A  wgEncodeAwgTfbsSydhImr90Pol2IggrabUniPk.narrow...
# 41      RAD21  wgEncodeAwgTfbsSydhImr90Rad21IggrabUniPk.narro...
# 42        RB1                        RB1-Chicas_peaks.narrowPeak
# 43       RBL2                       RBL2-Chicas_peaks.narrowPeak
# 44      RCOR1  wgEncodeSydhTfbsImr90Corestsc30189IggrabPk.nar...
# 45       RELA                         RELA-LICR_peaks.narrowPeak
# 46       RFX5       wgEncodeSydhTfbsImr90Rfx5IggrabPk.narrowPeak
# 47       YAP1                        YAP1-Stein_peaks.narrowPeak
#
#                  source    accession  identifier_col
# 0                ENCODE  ENCSR424FAZ               4
# 1                ENCODE     GSE31477               4
# 2                ENCODE     GSE31477               4
# 3                ENCODE     GSE31477               4
# 4   Roadmap Epigenomics     GSE18927               4
# 5            Jin et al.     GSE43070               4
# 6   Roadmap Epigenomics     GSE16256               4
# 7   Roadmap Epigenomics     GSE16256               4
# 8           Chen et al.     GSE54847               4
# 9   Roadmap Epigenomics     GSE16256               4
# 10  Roadmap Epigenomics     GSE16256               4
# 11  Roadmap Epigenomics     GSE16256               4
# 12  Roadmap Epigenomics     GSE16256               4
# 13  Roadmap Epigenomics     GSE16256               4
# 14  Roadmap Epigenomics     GSE16256               4
# 15  Roadmap Epigenomics     GSE16256               4
# 16  Roadmap Epigenomics     GSE16256               4
# 17  Roadmap Epigenomics     GSE16256               4
# 18  Roadmap Epigenomics     GSE16256               4
# 19  Roadmap Epigenomics     GSE16256               4
# 20  Roadmap Epigenomics     GSE16256               4
# 21  Roadmap Epigenomics     GSE16256               4
# 22  Roadmap Epigenomics     GSE16256               4
# 23  Roadmap Epigenomics     GSE16256               4
# 24  Roadmap Epigenomics     GSE16256               4
# 25  Roadmap Epigenomics     GSE16256               4
# 26  Roadmap Epigenomics     GSE16256               4
# 27  Roadmap Epigenomics     GSE16256               4
# 28  Roadmap Epigenomics     GSE16256               4
# 29  Roadmap Epigenomics     GSE16256               4
# 30  Roadmap Epigenomics     GSE16256               4
# 31  Roadmap Epigenomics     GSE16256               4
# 32  Roadmap Epigenomics     GSE16256               4
# 33  Roadmap Epigenomics     GSE16256               4
# 34  Roadmap Epigenomics     GSE16256               4
# 35          Otte et al.     GSE53332               4
# 36               ENCODE     GSE31477               4
# 37               ENCODE     GSE31477               4
# 38      Maunakea et al.     GSE47678               4
# 39               ENCODE     GSE31477               4
# 40               ENCODE     GSE31477               4
# 41               ENCODE     GSE31477               4
# 42        Chicas et al.     GSE19899               4
# 43        Chicas et al.     GSE19899               4
# 44               ENCODE     GSE31477               4
# 45           Jin et al.     GSE43070               4
# 46               ENCODE     GSE31477               4
# 47         Stein et al.     GSE61852               4

# %% [markdown]
# # Test: processing epigenomic features for all adhesome genes

# %% [markdown]
# ### Identify start and stop sites of each adhesome gene

# %%
# Load active adhesome genes
active_adhesome_genes = pickle.load(open(saving_dir+'active_adhesome_genes.pkl', 'rb'))
# Load gene location in hg19
gene_locations_filename = genome_dir+'chrom_hg19.loc_canonical'
gene_id_filename = genome_dir+'chrom_hg19.name'
df_loc = lu.get_gene_locations(gene_locations_filename, gene_id_filename)
# Find location of adhesome genes
adhesome_loc = df_loc[df_loc['geneSymbol'].isin(active_adhesome_genes)][['geneSymbol','#chrom','chromStart','chromEnd']]
adhesome_loc['geneLength'] = adhesome_loc['chromEnd']-adhesome_loc['chromStart']
adhesome_loc.columns = ['gene','chrom','start','end','length']
adhesome_loc = adhesome_loc.sort_values(by=['chrom','start'])
adhesome_loc.head()
# Out:
#         gene chrom     start       end  length
# 146   FBLIM1  chr1  16085254  16113084   27830
# 1548   ASAP3  chr1  23755055  23810750   55695
# 1588  SLC9A1  chr1  27425299  27481621   56322
# 1618   FABP3  chr1  31838099  31845923    7824
# 335    MACF1  chr1  39549838  39952810  402972

# %%
# Divide genome into portions corresponding to adhesome genes of interest 
df_adhesome_pos = adhesome_loc[['chrom','start','end']]

# %%
# Convert to bed file
bed_adhesome = pybedtools.BedTool.from_dataframe(df_adhesome_pos)
bed_adhesome_df = bed_adhesome.to_dataframe()

# %% [markdown]
# ### Call RNAseq peaks

# %%
# Get bed file of RNAseq
f = func_gen_table[func_gen_table['name']=='RNAseq'].iloc[0]['filename']
bed = pybedtools.BedTool(epigenome_dir + f).sort()
# Get counts for this feature in the segmented genome
out = pybedtools.bedtool.BedTool.map(bed_adhesome, bed, c = [2,3], o = 'count_distinct')
counts = out.to_dataframe()['name'].values
# Add results to tf_loc
adhesome_loc['RNAseq'] = counts
# Normalize by gene length
adhesome_loc['normRNAseq'] = np.log(1+1000000*adhesome_loc['RNAseq']/adhesome_loc['length'])
# z-score
mean = adhesome_loc['normRNAseq'].mean()
std = adhesome_loc['normRNAseq'].std()
adhesome_loc['z_RNAseq'] = (adhesome_loc['normRNAseq']-mean)/std
adhesome_loc.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-53937b07f879> in <module>
#       1 # Get bed file of RNAseq
#       2 f = func_gen_table[func_gen_table['name']=='RNAseq'].iloc[0]['filename']
# ----> 3 bed = pybedtools.BedTool(epigenome_dir + f).sort()
#       4 # Get counts for this feature in the segmented genome
#       5 out = pybedtools.bedtool.BedTool.map(bed_adhesome, bed, c = 4, o = 'count_distinct')
#
# ~/anaconda3/lib/python3.7/site-packages/pybedtools/bedtool.py in decorated(self, *args, **kwargs)
#     915             # this calls the actual method in the first place; *result* is
#     916             # whatever you get back
# --> 917             result = method(self, *args, **kwargs)
#     918
#     919             # add appropriate tags
#
# ~/anaconda3/lib/python3.7/site-packages/pybedtools/bedtool.py in wrapped(self, *args, **kwargs)
#     399                 stdin=stdin,
#     400                 check_stderr=check_stderr,
# --> 401                 decode_output=decode_output,
#     402             )
#     403
#
# ~/anaconda3/lib/python3.7/site-packages/pybedtools/helpers.py in call_bedtools(cmds, tmpfn, stdin, check_stderr, decode_output, encode_input)
#     427                 cmds, stdout=outfile, stderr=subprocess.PIPE, bufsize=BUFSIZE
#     428             )
# --> 429             stdout, stderr = p.communicate()
#     430             output = tmpfn
#     431             outfile.close()
#
# ~/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     927                 self.stdout.close()
#     928             elif self.stderr:
# --> 929                 stderr = self.stderr.read()
#     930                 self.stderr.close()
#     931             self.wait()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Call ChIP-seq peaks

# %%
# Get bed file of feature
f = func_gen_table[func_gen_table['name']=='H3K4me1'].iloc[0]['filename']
bed = pybedtools.BedTool(epigenome_dir + f).sort()
# Get counts for this feature in the segmented genome
out = pybedtools.bedtool.BedTool.map(bed_adhesome, bed, c = [2,3], o = 'count_distinct')
counts = out.to_dataframe()['name'].values
# Add results to tf_loc
adhesome_loc['H3K4me1'] = counts
# Normalize by gene length
adhesome_loc['normH3K4me1'] = np.log(1+1000000*adhesome_loc['H3K4me1']/adhesome_loc['length'])
# z-score
mean = adhesome_loc['normH3K4me1'].mean()
std = adhesome_loc['normH3K4me1'].std()
adhesome_loc['z_H3K4me1'] = (adhesome_loc['normH3K4me1']-mean)/std
adhesome_loc.head()
# Out:
#         gene chrom     start       end  length  H3K4me1  normH3K4me1  \
# 146   FBLIM1  chr1  16085254  16113084   27830       14     6.222684
# 1548   ASAP3  chr1  23755055  23810750   55695       16     5.663929
# 1588  SLC9A1  chr1  27425299  27481621   56322       31     6.312472
# 1618   FABP3  chr1  31838099  31845923    7824        2     5.547611
# 335    MACF1  chr1  39549838  39952810  402972      231     6.353049
#
#       z_H3K4me1
# 146    0.505034
# 1548  -0.004947
# 1588   0.586985
# 1618  -0.111111
# 335    0.624019

# %% [markdown]
# # Load processing of all epigenomic features

# %%
# Load processing of all epigenomic features
adhesome_loc = pickle.load(open(saving_dir+'adhesome_with_epigenomics.pkl', 'rb'))
adhesome_loc = adhesome_loc[[col for col in adhesome_loc.columns if ('z_' in col) or (col == 'gene')]]
adhesome_loc = adhesome_loc.set_index('gene').transpose()
adhesome_loc
# Out:
# gene           FBLIM1     ASAP3    SLC9A1     FABP3     MACF1     PTPRF  \
# z_LMNB1      1.058640 -0.058131  0.486024 -1.370996 -0.234386  0.533161
# z_MAFK       1.209062 -1.240573  0.814356 -1.240573  0.616374  0.168043
# z_MAZ        0.693485  0.298577  0.686715  1.024301 -0.190802  0.528910
# z_MECP2     -0.590850 -0.590850  1.755455 -0.590850 -0.590850  1.695994
# z_MXI1       0.510812  0.510478  0.139879  1.194659  0.197909  0.607965
# z_POLR2A     0.654195  0.317913  0.312569 -1.165329 -0.089706 -1.165329
# z_RAD21     -1.304917 -1.304917  1.160385 -1.304917  0.655525  0.403103
# z_RB1       -0.175397  3.748043  3.733905 -0.175397 -0.175397 -0.175397
# z_RBL2      -0.274687 -0.274687 -0.274687 -0.274687  1.441255 -0.274687
# z_RCOR1     -0.848740  0.896614  1.285498 -0.848740  0.691218 -0.848740
# z_RELA      -0.214212 -0.214212 -0.214212 -0.214212 -0.214212 -0.214212
# z_RFX5      -0.290205  4.400464 -0.290205 -0.290205 -0.290205 -0.290205
# z_YAP1      -1.014468 -1.014468  0.973299 -1.014468  1.066090  0.348110
#
# gene           TSPAN1   ITGB3BP      NEXN     BCAR3    ...      SHARPIN  \
# z_RNAseq    -1.600105 -0.780127  0.814906  0.091090    ...     0.839832
# z_CEBPB      0.805996  0.072477 -0.085771  0.855242    ...    -1.745508
# z_CHD1      -0.679852 -0.679852 -0.679852  0.670238    ...     2.452693
# z_CTCF       0.900177  0.137673 -0.026827  0.156964    ...    -1.752147
# z_DNase-seq  0.151453 -1.124482 -0.355407  0.275570    ...     1.004239
# z_EP300      1.018960  0.366696  0.559745  0.383198    ...    -1.249900
# z_H2AK5ac    1.132940 -1.106101 -0.089535  0.649290    ...     0.432934
# z_H2AK9ac    0.976756 -2.649447 -0.431726 -0.477459    ...     1.383296
# z_H2AY      -0.455870  1.104735 -0.455870 -0.455870    ...    -0.455870
# z_H2AZ       1.282438 -0.619821 -0.346251 -1.323576    ...     0.771818
# z_H2BK120ac  1.059283 -0.446999  0.180598  0.692020    ...     0.510464
# z_H2BK12ac   0.847430 -0.350865  0.484306  0.733142    ...    -1.793962
# z_H2BK15ac   1.096844 -0.140319  0.407453  0.810633    ...    -1.515997
# z_H2BK20ac   1.123376  0.002485  0.539986  0.904756    ...    -1.347395
# z_H2BK5ac    0.513714 -0.795276  0.382791  0.514451    ...     0.875711
# z_H3K14ac    0.663334 -0.645415  0.198780  0.811781    ...     0.251831
# z_H3K18ac    0.771234 -0.671305  0.176710  0.792484    ...     0.626564
# z_H3K23ac    0.504147 -0.374304  0.495356  0.791908    ...     0.283205
# z_H3K27ac   -0.241998 -1.004621  0.524824  0.628502    ...     0.143568
# z_H3K27me3  -0.502787 -0.502787 -0.502787 -0.502787    ...    -0.502787
# z_H3K36me3  -2.568170 -1.064299  0.687322  0.496641    ...     0.493063
# z_H3K4ac     0.965538 -1.554310  0.078360  0.749054    ...     0.846995
# z_H3K4me1   -0.042748 -0.990050 -0.629270  0.958997    ...     0.561523
# z_H3K4me2    0.762431 -0.705835  0.181531  0.725457    ...     0.738422
# z_H3K4me3   -2.629751 -0.781251 -0.034558  0.067982    ...     1.096918
# z_H3K56ac    0.601106 -0.442629  0.231491  0.467441    ...     0.947827
# z_H3K79me1  -2.125340 -0.254224  0.524861  0.727992    ...     0.520177
# z_H3K79me2  -2.121138 -0.543600  0.588452  0.744511    ...     0.536028
# z_H3K9ac     0.966729 -1.000818 -0.181034  0.324506    ...     0.249847
# z_H3k9me1    0.603442 -0.121836  0.251134  0.970640    ...    -2.338632
# z_H3K9me3   -0.846336  0.469193  1.000594  0.820410    ...    -0.846336
# z_H4K20me1  -1.928419 -0.897891  0.605410  0.867686    ...     0.587494
# z_H4K5ac     0.848585 -1.077201  0.446465  0.676501    ...     0.830313
# z_H4K8ac     0.852366 -0.452410  0.430818  0.476750    ...     1.005824
# z_H4K91ac    1.064250 -0.725369 -0.188947  0.495334    ...     0.874203
# z_LMNB1      0.487783 -0.923904  0.331457  0.233750    ...     0.817193
# z_MAFK      -1.240573 -1.240573  0.443001  1.093668    ...    -1.240573
# z_MAZ        0.834289 -1.796644 -0.085239  0.258518    ...     1.216686
# z_MECP2     -0.590850 -0.590850 -0.590850 -0.590850    ...     2.793802
# z_MXI1      -1.464805 -0.055695 -1.464805  0.591674    ...     1.376031
# z_POLR2A     1.119029 -1.165329  0.320631 -0.037700    ...     1.451052
# z_RAD21      1.178911  0.464847  0.310797  0.635334    ...    -1.304917
# z_RB1       -0.175397  3.257452 -0.175397 -0.175397    ...    -0.175397
# z_RBL2      -0.274687  2.199085 -0.274687 -0.274687    ...    -0.274687
# z_RCOR1     -0.848740 -0.848740 -0.848740  0.856802    ...    -0.848740
# z_RELA      -0.214212 -0.214212 -0.214212 -0.214212    ...    -0.214212
# z_RFX5      -0.290205 -0.290205 -0.290205 -0.290205    ...    -0.290205
# z_YAP1      -1.014468  0.407840  0.982375  0.941197    ...    -1.014468
#
# gene            TESK1      TLN1     OSTF1    SPTLC1    CORO2A       ENG  \
# z_RNAseq     0.461933  1.301908 -0.424172 -0.056108 -0.747507  0.342613
# z_CEBPB      1.268629  0.160717 -0.116951  0.563210 -0.222575 -1.745508
# z_CHD1      -0.679852 -0.679852 -0.679852 -0.679852 -0.679852 -0.679852
# z_CTCF      -1.752147  0.859113 -0.059239 -1.752147 -1.752147 -1.752147
# z_DNase-seq  0.670461  0.231391 -0.135593 -0.317266 -0.389103  0.425602
# z_EP300     -1.249900  0.783688  0.531251  0.803068 -1.249900 -1.249900
# z_H2AK5ac   -2.979993  0.242434 -0.915356  0.167460 -0.507995 -2.979993
# z_H2AK9ac    1.059084  0.880114 -0.874736 -1.081768  0.320853 -2.649447
# z_H2AY      -0.455870 -0.455870 -0.455870 -0.455870 -0.455870 -0.455870
# z_H2AZ       1.377636  0.254722  0.095023 -0.634199  0.598189 -2.910696
# z_RELA      -0.214212 -0.214212 -0.214212 -0.214212 -0.214212 -0.214212
# z_RFX5      -0.290205  5.106946  4.320778 -0.290205 -0.290205 -0.290205
# z_YAP1      -1.014468  0.855938 -1.014468  0.974694 -1.014468 -1.014468
#
# gene             ABL1   RAPGEF1      VAV2
# z_RNAseq    -0.330950 -0.009603 -0.416993
# z_CEBPB      0.732887  0.747249 -0.106801
# z_CHD1       0.845080  0.612954 -0.679852
# z_CTCF       0.425573  0.259076 -0.048689
# z_DNase-seq  0.414863  0.028026  0.166418
# z_EP300      0.736110  0.668173 -0.113244
# z_H2AK5ac    0.565718  0.742246 -0.028570
# z_H2AK9ac    0.006473  0.119803  0.690273
# z_H2AY      -0.455870 -0.455870 -0.455870
# z_H2AZ      -0.022909 -0.192599  0.549696
# z_H2BK120ac  0.609248  0.712765  0.136801
# z_H2BK12ac   0.788892  0.810411 -0.144432
# z_H2BK15ac   0.803343  0.985179 -0.390896
# z_H2BK20ac   0.749307  1.039656  0.404972
# z_H2BK5ac    0.454991  0.282937  0.173844
# z_H3K14ac    0.523850  0.548832 -0.102954
# z_H3K18ac    0.635598  0.595792 -0.152828
# z_H3K23ac    0.635489  0.348506 -0.163554
# z_H3K27ac    0.547603  0.279858 -0.002192
# z_H3K27me3  -0.502787  1.277953 -0.502787
# z_H3K36me3   0.131677  0.441489  0.494625
# z_H3K4ac     0.553033  0.605476 -0.043128
# z_H3K4me1    0.590237  0.571376  0.448975
# z_H3K4me2    0.359032  0.245888 -0.456618
# z_H3K4me3    0.359987 -0.162476 -0.062113
# z_H3K56ac    0.494017  0.230854 -0.200449
# z_H3K79me1   0.654539  0.449574  0.560477
# z_H3K79me2   0.726979  0.509826  0.673268
# z_H3K9ac     0.513876  0.307478  0.110563
# z_H3k9me1    0.520191  0.705072  0.371007
# z_H3K9me3    1.281381  0.248219  1.039584
# z_H4K20me1   0.702383  0.586227  0.760223
# z_H4K5ac     0.546805  0.422601 -0.028153
# z_H4K8ac     0.523079  0.322058 -0.064854
# z_H4K91ac    0.548456  0.585679  0.048347
# z_LMNB1      0.289665  0.097576  0.575010
# z_MAFK       0.798707  1.033701  0.056041
# z_MAZ        0.049033  0.037518  0.405816
# z_MECP2     -0.590850  0.806001  1.131201
# z_MXI1      -0.419204  0.053914  0.244342
# z_POLR2A     0.976888 -0.085545 -0.320793
# z_RAD21      0.652165  0.877687  0.142489
# z_RB1       -0.175397 -0.175397 -0.175397
# z_RBL2      -0.274687 -0.274687 -0.274687
# z_RCOR1      0.649997  0.421859  0.717666
# z_RELA      -0.214212 -0.214212 -0.214212
# z_RFX5       2.755189 -0.290205 -0.290205
# z_YAP1       1.041108  0.883949  0.239769
#
# [48 rows x 219 columns]

# %%
# Compute Spearman correlation between adhesome genes
adhesome_loc_corr = adhesome_loc.corr(method='spearman')
pickle.dump(adhesome_loc_corr, open(saving_dir+'adhesome_loc_corr.pkl','wb'))
