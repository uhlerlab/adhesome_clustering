# %%
# Import standard libraries
import os
from importlib import reload
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import pandas as pd
import pickle
import itertools
from itertools import groupby
import os.path
import math
import pybedtools
import time
from tqdm import tqdm
import random
import MOODS.parsers
import MOODS.tools
import MOODS.scan
import subprocess
# Custom libraries
import utils as lu
import process_jaspar_without_strand as pj
# Reload modules in case of modifications
reload(lu)
reload(pj)
# Out:
# <module 'process_jaspar_without_strand' from '/home/louiscam/projects/gpcr/code/JASPAR_processing/process_jaspar_without_strand.py'>

# %% [markdown]
# # Directories

# %%
# Directory of adhesome data
dir_adhesome = '/home/louiscam/projects/gpcr/data/adhesome_data/'
# Directory of genome data
dir_genome = '/home/louiscam/projects/gpcr/data/genome_data/'
prom_hg19_seq_dir = dir_genome+'prom_hg19_seq_dir/'
# Directory of processed HiC
dir_processed_hic = '/home/louiscam/projects/gpcr/save/processed_hic_data_dir/'
# Directory for storing preliminary results
prelim_results_dir = '/home/louiscam/projects/gpcr/save/prelim_results_dir/'
# Directory of epigenomic data
epigenome_dir = '/home/louiscam/projects/gpcr/data/epigenome_data/'
processed_epigenome_data_dir = '/home/louiscam/projects/gpcr/save/processed_epigenome_data_dir/'
# Saving directory
saving_dir = '/home/louiscam/projects/gpcr/save/figures/'
# Directory of tf data
tf_dir = '/home/louiscam/projects/gpcr/data/tf_data/'
jaspar_dir = tf_dir+'jaspar_data/'
pfm_dir = tf_dir+'pfm_data/'
fantom5_dir = '/home/louiscam/projects/gpcr/data/fantom5/'
moods_out_dir = tf_dir+'moods_cage_outdir_without_strand/'
cage_fasta_dir = dir_genome+'cage_hg19_seq_dir_without_strand/'

# %% [markdown]
# # 1. Select genes of interest

# %% [markdown]
# ### Load genes of interest (active adhesome genes)

# %%
# Genes of interest and location
selected_genes = pickle.load(open(saving_dir+'active_adhesome_genes.pkl', 'rb'))
print('Number of genes of interest = '+str(len(selected_genes)))
# Out:
# Number of genes of interest = 219

# %%
# Mapping UCSC to HGNC
ucsc_to_hgnc = pj.create_ucsc_hgnc_dict(dir_genome+'chrom_hg19.name')

# %% [markdown]
# ### Load human TFs list
# from http://humantfs.ccbr.utoronto.ca/

# %%
# Load TFs
tf_df = pd.read_csv(dir_genome+'human_tf.database', sep='\t', header=0, index_col=0)
tf_df = tf_df[tf_df['Is TF?']=='Yes'].sort_values(by=['HGNC symbol'])
all_tfs = tf_df['HGNC symbol'].values
print('Total number of TFs = '+str(len(all_tfs)))
# Out:
# Total number of TFs = 1639

# %% [markdown]
# ### Gene location

# %%
# Load gene location dataframe
gene_id_filename = dir_genome+'chrom_hg19.name'
gene_locations_filename = dir_genome+'chrom_hg19.loc_canonical'
df_loc = lu.get_gene_locations(gene_locations_filename, gene_id_filename)
df_loc.columns = ['transcript','gene','chrom','gene_start','gene_end','clusterId','protein']
df_loc['gene_length'] = df_loc['gene_end']-df_loc['gene_start']
df_loc['gene_center'] = df_loc['gene_start']+df_loc['gene_length']//2
# Restrict to selected genes
df_loc = df_loc[df_loc['gene'].isin(selected_genes)]
# Add TF information
df_loc['isTF'] = [df_loc['gene'].iloc[i] in all_tfs for i in range(df_loc.shape[0])]

# %%
# Visualize distribution of gene lengths
print('adhesome gene lengths quartile = '+str(np.quantile(df_loc['gene_length'].values, [0.25,0.5,0.75])))
plt.figure()
plt.hist(df_loc['gene_length'], bins=np.arange(0,1000000,5000))
plt.xlabel('gene length')
plt.ylabel('number of genes')
plt.title('histogram of adhesome gene lengths')
plt.show()
# Out:
# adhesome gene lengths quartile = [ 21507.   49385.  114977.5]

# %%
# Determine gene windows (1 locus centered at the gene)
df_loc['gene_window_start'] = df_loc['gene_center']-250000//2
df_loc['gene_window_end'] = df_loc['gene_center']+250000//2

# %%
# Visualize results
df_loc.head()
# Out:
#        transcript  gene  chrom  gene_start   gene_end  clusterId     protein  \
# 3334   uc001isx.3  ABI1  chr10    27035524   27150016       3074  uc001isx.3
# 15824  uc002uzz.3  ABI2   chr2   204193002  204296892      17484  uc002uzz.3
# 11717  uc002iop.1  ABI3  chr17    47287588   47300587      13058  uc002iop.1
# 27778  uc004bzv.3  ABL1   chr9   133589267  133763062      30188  uc004bzv.3
# 25716  uc003sot.4  ACTB   chr7     5566778    5570232      26639  uc003sot.4
#
#        gene_length  gene_center   isTF  gene_window_start  gene_window_end
# 3334        114492     27092770  False           26967770         27217770
# 15824       103890    204244947  False          204119947        204369947
# 11717        12999     47294087  False           47169087         47419087
# 27778       173795    133676164  False          133551164        133801164
# 25716         3454      5568505  False            5443505          5693505

# %% [markdown]
# # 2. Select CAGE peaks

# %% [markdown]
# ### Process robust CAGE peaks

# %%
# Load annotated FANTOM5 CAGE peaks
cage_df = pd.read_csv(fantom5_dir+'hg19.cage_peak_phase1and2combined_ann.txt', sep='\t', skiprows=7, header=0)
# Define new columns
cage_df['chrom'] = cage_df['00Annotation'].str.split(':', expand=True)[0]
cage_df['cage_start'] = cage_df['00Annotation'].str.split(':', expand=True)[1].str.split(",", expand=True)[0].str.split(".", expand=True)[0].astype(int)
cage_df['cage_end'] = cage_df['00Annotation'].str.split(':', expand=True)[1].str.split(",", expand=True)[0].str.split(".", expand=True)[2].astype(int)
cage_df['strand'] = cage_df['00Annotation'].str.split(':', expand=True)[1].str.split(",", expand=True)[1]
cage_df['peak_id'] = cage_df['short_description'].str.split('@', expand=True)[0].str.strip('p')
# Reformat dataframe
cage_df = cage_df[['short_description','association_with_transcript','chrom','cage_start','cage_end',
                   'strand','peak_id']]
cage_df = cage_df.sort_values(by=['chrom','cage_start'])
print('Number of unique CAGE peaks = '+str(len(np.unique(cage_df['short_description'].values))))
cage_df.head()
# Out:
# Number of unique CAGE peaks = 201802
#       short_description    association_with_transcript chrom  cage_start  \
# 95563       p1@MTND1P23  129bp_to_ENST00000416931_5end  chr1      564571
# 95564       p3@MTND1P23  197bp_to_ENST00000416931_5end  chr1      564639
# 95565       p3@MTND2P28  246bp_to_ENST00000457540_5end  chr1      565266
# 95566       p4@MTND2P28  458bp_to_ENST00000457540_5end  chr1      565478
# 95567       p1@MTND2P28  489bp_to_ENST00000457540_5end  chr1      565509
#
#        cage_end strand peak_id
# 95563    564600      +       1
# 95564    564649      +       3
# 95565    565278      +       3
# 95566    565483      +       4
# 95567    565541      +       1

# %% [markdown]
# ### CAGE peaks within selected gene windows

# %%
# Create bed file for regions upstream of genes of interest
gene_window_df = df_loc[['chrom','gene_window_start','gene_window_end','gene']]
gene_window_df.columns = ['chrom','start','stop','name']
gene_window_bed = pybedtools.BedTool.from_dataframe(gene_window_df).sort()

# %%
# Create a bed file for robust CAGE peaks
cage_peak_df = cage_df[['chrom','cage_start','cage_end','short_description']]
cage_peak_df.columns = ['chrom','start','end','name']
cage_bed = pybedtools.BedTool.from_dataframe(cage_peak_df).sort()

# %%
# Get CAGE peaks for each gene of interest
out = pybedtools.bedtool.BedTool.map(gene_window_bed, cage_bed, c = 4, o = 'distinct')
out_df = out.to_dataframe()
out_df.columns=['chrom','gene_window_start','gene_window_end','gene','peaks']
out_df['peaks'] = out_df['peaks'].str.replace(',p',';p')

# %%
# Reformat matching results
peaks_per_gene_df = pd.merge(df_loc, out_df, on=['chrom','gene_window_start','gene_window_end','gene'])
peaks_per_gene_df = peaks_per_gene_df[peaks_per_gene_df['peaks'] != '.']
peaks_per_gene_df['peaks'] = peaks_per_gene_df['peaks'].str.split(';')
peaks_per_gene_df['n_peaks'] = [len(peaks) for peaks in peaks_per_gene_df['peaks']]
peaks_per_gene_df = peaks_per_gene_df[['gene', 'isTF', 'chrom', 'gene_start', 'gene_end', 'gene_length',
                                       'gene_window_start', 'gene_window_end','peaks','n_peaks']]

# %%
# Visualize results
peaks_per_gene_df.head()
# Out:
#    gene   isTF  chrom  gene_start   gene_end  gene_length  gene_window_start  \
# 0  ABI1  False  chr10    27035524   27150016       114492           26967770
# 1  ABI2  False   chr2   204193002  204296892       103890          204119947
# 2  ABI3  False  chr17    47287588   47300587        12999           47169087
# 3  ABL1  False   chr9   133589267  133763062       173795          133551164
# 4  ACTB  False   chr7     5566778    5570232         3454            5443505
#
#    gene_window_end                                              peaks  n_peaks
# 0         27217770  [p10@PDSS1, p11@PDSS1, p12@PDSS1, p1@ABI1, p1@...       35
# 1        204369947  [p1@ABI2, p2@ABI2, p3@ABI2, p4@ABI2, p5@ABI2, ...       17
# 2         47419087  [p1@ABI3, p1@B4GALNT2, p1@FLJ40194, p1@GNGT2, ...       35
# 3        133801164  [p1@ABL1, p1@AF533988, p1@EXOSC2, p1@M14755, p...       21
# 4          5693505  [p10@ACTB, p10@TNRC18, p11@ACTB, p12@ACTB, p13...       79

# %%
# Histogram of number of peaks per gene
plt.figure()
plt.hist(peaks_per_gene_df['n_peaks'], bins=np.arange(0,110,1))
plt.xlabel('number of peaks')
plt.ylabel('number of genes')
plt.title('histogram of number of peaks per gene')
plt.show()

# %% [markdown]
# # 3. Associate CAGE peaks with genes

# %%
# Dataframe of genes for each peak
genes_per_peak = peaks_per_gene_df[['gene','peaks']]
genes_per_peak = lu.unnesting(genes_per_peak,['peaks'])
genes_per_peak = genes_per_peak.groupby('peaks')['gene'].apply(list).reset_index(name='genes')
genes_per_peak['n_genes'] = [len(genes) for genes in genes_per_peak['genes']]
genes_per_peak.columns = ['short_description','genes','n_genes']

# %%
# Add peak location
genes_per_peak = pd.merge(genes_per_peak, cage_df, on=['short_description'])
genes_per_peak = genes_per_peak[['short_description','chrom','cage_start','cage_end','strand','genes']]
genes_per_peak = genes_per_peak.sort_values(by=['chrom'])

# %%
# Consider a window around each peak
genes_per_peak['cage_window_start'] = genes_per_peak['cage_start']-400
genes_per_peak['cage_window_end'] = genes_per_peak['cage_end']+400

# %%
# Visualize
genes_per_peak.head()
# Out:
#      short_description chrom  cage_start   cage_end strand    genes  \
# 3103           p2@TPM3  chr1   154164569  154164584      -   [HAX1]
# 4130          p4@DCST2  chr1   155006254  155006259      -   [SHC1]
# 781          p1@ADAM15  chr1   155023757  155023833      +   [SHC1]
# 1763        p1@SERINC2  chr1    31886034   31886099      +  [FABP3]
# 4134         p4@DNAJB4  chr1    78444874   78444905      +   [NEXN]
#
#       cage_window_start  cage_window_end
# 3103          154164169        154164984
# 4130          155005854        155006659
# 781           155023357        155024233
# 1763           31885634         31886499
# 4134           78444474         78445305

# %% [markdown]
# # 4. Create sequence files for all CAGE windows

# %% [raw]
# # Loop over all CAGE windows to generate sequence files
# for i in tqdm(range(genes_per_peak.shape[0])):
#     time.sleep(.01)
#     # Peak characteristics
#     peak = genes_per_peak['short_description'].iloc[i]
#     chrom = genes_per_peak['chrom'].iloc[i]
#     start = genes_per_peak['cage_window_start'].iloc[i]
#     end = genes_per_peak['cage_window_end'].iloc[i]
#     # Generate window sequence
#     result = subprocess.run(cage_fasta_dir+'twoBitToFa http://hgdownload.cse.ucsc.edu/gbdb/hg19/hg19.2bit '+
#                             cage_fasta_dir+peak+'.fa'+
#                             ' -seq='+chrom+' -start='+str(start)+' -end='+str(end)+' -noMask',
#                             shell=True)

# %% [markdown]
# # 5. Search for TFBS in all CAGE windows
# See process_JASPAR_without_strand.py

# %% [markdown]
# # 6. Find TFs binding each CAGE window

# %% [markdown]
# ### Useful data

# %%
# Load JASPAR TFBS metadata
jaspar_df = pd.read_csv(tf_dir+'JASPAR-HomoSapiens.csv', 
                        header=0, usecols=['ID','Name','Species','Class','Family'])
# Mapping JASPAR ID to HGNC
jasparid_to_hgnc = {jaspar_df.iloc[i,0]:jaspar_df.iloc[i,1] for i in range(jaspar_df.shape[0])}

# %%
# Visualize data
print('Number of unique TFs = '+str(len(np.unique(jaspar_df['Name']))))
print('Number of unique TF motifs = '+str(len(np.unique(jaspar_df['ID']))))
jaspar_df.head()
# Out:
# Number of unique TFs = 639
# Number of unique TF motifs = 810
#          ID    Name       Species                                  Class  \
# 0  MA0002.1   RUNX1  Homo sapiens                    Runt domain factors
# 1  MA0003.1  TFAP2A  Homo sapiens  Basic helix-span-helix factors (bHSH)
# 2  MA0003.2  TFAP2A  Homo sapiens  Basic helix-span-helix factors (bHSH)
# 3  MA0003.3  TFAP2A  Homo sapiens  Basic helix-span-helix factors (bHSH)
# 4  MA0003.4  TFAP2A  Homo sapiens  Basic helix-span-helix factors (bHSH)
#
#                  Family
# 0  Runt-related factors
# 1                  AP-2
# 2                  AP-2
# 3                  AP-2
# 4                  AP-2

# %% [markdown]
# ### Load MOODS results

# %%
# Create dictionary mapping CAGE peaks to the corresponding TFs
tfs_associated_to_cage_peaks = {}

# %% [raw]
# # Loop over files in moods_out_dir and summarize results
# for peak_moods_file in tqdm(os.listdir(moods_out_dir)):
#     time.sleep(.01)
#     # load results dataframe for that gene
#     cage_peak = peak_moods_file.strip('.txt')
#     res_df = pd.read_csv(moods_out_dir+peak_moods_file, sep=',', header=None,
#                          usecols=[0,1,2,3,4,5],
#                          names=['peak_id','tfbs_file','motif_loc','strand','score','motif'])
#     # Add columns corresponding to the target gene
#     res_df['cage_peak'] = cage_peak
#     res_df['chrom'] = res_df['peak_id'].str.split(':', expand=True)[0]
#     location_cols = res_df['peak_id'].str.split(':', expand=True)[1]
#     res_df[['start','stop']] = location_cols.str.split('-', expand=True)
#     # Add columns corresponding to the TFBS
#     res_df['jaspar_tfbs'] = res_df['tfbs_file'].str.strip('.pfm')
#     res_df['TF'] = [jasparid_to_hgnc[jaspar_id] for jaspar_id in res_df['jaspar_tfbs']]
#     # Select relevant columns
#     res_df = res_df[['cage_peak', 'chrom','start','stop','motif_loc',
#                      'jaspar_tfbs','TF','score','strand','motif']]
#     # Store list of TFs associated with the current CAGE peak in dict
#     tfs_associated_to_cage_peaks[cage_peak] = np.sort(np.unique(res_df['TF'].values))
# pickle.dump(tfs_associated_to_cage_peaks, open(saving_dir+'tfs_cage_without_strand.pkl', 'wb'))

# %% [markdown]
# # 7. Find TFs targeting genes of interest

# %%
# Load mapping between cage peaks and corresponding TFs
tfs_associated_to_cage_peaks = pickle.load(open(saving_dir+'tfs_cage_without_strand.pkl', 'rb'))

# %%
# Construct dataframe with gene-tf pairs
tf_and_genes_df = genes_per_peak.copy()
tf_and_genes_df['tfs'] = [tfs_associated_to_cage_peaks[cage_peak] if cage_peak in tfs_associated_to_cage_peaks.keys()
                          else ['missing']
                          for cage_peak in tf_and_genes_df['short_description'].values]
tf_and_genes_df = lu.unnesting(tf_and_genes_df,['genes'])
gene_to_tfs = {tf_and_genes_df.iloc[i,0]:tf_and_genes_df.iloc[i,8] for i in range(tf_and_genes_df.shape[0])}
tf_and_genes_df = lu.unnesting(tf_and_genes_df,['tfs'])
tf_and_genes_df = tf_and_genes_df[['genes','tfs','short_description','chrom','cage_start','cage_end','strand']]
tf_and_genes_df = tf_and_genes_df.sort_values(by=['genes','tfs'])

# %%
# Visualize results
tf_and_genes_df.head()
# Out:
#      genes    tfs             short_description  chrom  cage_start  cage_end  \
# 3290  ABI1   ALX3                       p3@ABI1  chr10    27149904  27149920
# 5957  ABI1   ALX3  p@chr10:27149163..27149213,+  chr10    27149163  27149213
# 3290  ABI1  ARGFX                       p3@ABI1  chr10    27149904  27149920
# 5940  ABI1  ARGFX  p@chr10:26980007..26980015,+  chr10    26980007  26980015
# 5954  ABI1  ARGFX  p@chr10:27145359..27145362,-  chr10    27145359  27145362
#
#      strand
# 3290      -
# 5957      +
# 3290      -
# 5940      +
# 5954      -

# %%
# Save dictionary mapping selected genes to their potential TFs to pickle
pickle.dump(gene_to_tfs, open(saving_dir+'gene_to_tfs_without_strand.pkl', 'wb'))
gene_to_tfs
# Out:
# {'KTN1': array(['FOXG1', 'FOXI1', 'FOXL1', 'FOXN3', 'FOXO3', 'FOXO4', 'FOXO6',
#         'FOXP3', 'HOXA4', 'MZF1', 'NFATC2', 'RARA::RXRG', 'SNAI3',
#         'TCF7L1', 'THRB(var.3)', 'ZNF135'], dtype=object),
#  'FERMT1': array(['EBF1', 'EBF3', 'EHF', 'ELF1', 'ELF3', 'ETV1', 'ETV2',
#         'EWSR1-FLI1', 'GABPA', 'HOXA4', 'IKZF1', 'MAFF', 'MAFG',
#         'MAX::MYC', 'MNT', 'MYC', 'NFATC2', 'PLAG1', 'RELB', 'SPIC',
#         'THAP11', 'ZBTB12', 'ZNF354C'], dtype=object),
#  'KCNH2': array(['ATOH1(var.2)', 'BARHL2', 'CENPB', 'DPRX', 'EN2', 'GATA1', 'GATA6',
#         'GSC', 'IRF2', 'IRF7', 'IRF8', 'IRF9', 'MYF5', 'MYOD1', 'NFYA',
#         'NFYB', 'NFYC', 'NR1H2::RXRA', 'POU3F3', 'STAT1::STAT2',
#         'THRB(var.3)'], dtype=object),
#  'ACTB': array(['BARX2', 'EWSR1-FLI1', 'FOXN3', 'FOXP2', 'HNF1A', 'HNF1B', 'LEF1',
#         'MAZ', 'OSR2', 'SP2', 'THAP11', 'ZKSCAN5', 'ZNF135', 'ZNF148',
#         'ZNF263', 'ZNF354C', 'ZNF384', 'ZNF460'], dtype=object),
#  'VAV1': array(['EWSR1-FLI1', 'IKZF1', 'OSR1', 'PBX3', 'PKNOX1', 'REL', 'RELA',
#         'RUNX3', 'SPI1', 'SPIB', 'ZNF24'], dtype=object),
#  'ANKRD28': array(['BCL6', 'EWSR1-FLI1', 'GRHL2', 'NFYB', 'TFAP2B(var.2)',
#         'TFAP2C(var.2)', 'TFAP2E', 'ZNF16'], dtype=object),
#  'ITGA10': array(['EBF3', 'MAZ', 'PRDM1', 'TBR1', 'TBX2', 'ZNF148', 'ZNF682'],
#        dtype=object),
#  'ARF1': array(['CENPB', 'ELF1', 'EOMES', 'ETV1', 'GABPA', 'IKZF1', 'KLF14',
#         'KLF15', 'KLF16', 'KLF5', 'MGA', 'SP1', 'SP3', 'SP4', 'SP8', 'SP9',
#         'TBR1', 'TBX1', 'TBX15', 'TBX18', 'TBX2', 'TBX20', 'TBX21', 'TBX3',
#         'TBX4', 'TBX5', 'TBX6'], dtype=object),
#  'ARHGAP24': array(['ASCL1', 'BARX1', 'BHLHA15(var.2)', 'FOXC2', 'FOXD2', 'FOXE1',
#         'FOXN3', 'MAZ', 'MYOG', 'NFIB', 'NFIC(var.2)', 'NFIC::TLX1',
#         'NFIX(var.2)', 'NHLH1', 'NR4A2', 'PHOX2B', 'RARA(var.2)',
#         'RARA::RXRA', 'RARA::RXRG', 'SIX1', 'SMAD2::SMAD3::SMAD4',
#         'ZNF148', 'ZNF16'], dtype=object),
#  'ARHGEF12': array(['ISL2', 'KLF2', 'KLF3', 'NFIB', 'NFIC(var.2)', 'NFIC::TLX1',
#         'NFIX(var.2)', 'SNAI2', 'SNAI3', 'ZBTB6', 'ZNF135', 'ZNF460'],
#        dtype=object),
#  'ARHGEF2': array(['HOXB13', 'IRF1', 'KLF15', 'MZF1(var.2)', 'POU1F1', 'POU2F1',
#         'POU2F3', 'POU3F1', 'POU3F2', 'POU3F3', 'POU3F4', 'POU5F1B',
#         'PRDM1', 'RARG(var.3)', 'SP9', 'ZNF148', 'ZNF652'], dtype=object),
#  'ARHGEF7': array(['ATF2', 'CREB1', 'CREM', 'NFATC2', 'RARA::RXRA', 'SPI1', 'TFE3',
#         'TFEC', 'ZEB1', 'ZNF143', 'ZNF684'], dtype=object),
#  'ITGAD': array(['KLF13', 'TCF7', 'TCF7L2', 'ZNF317'], dtype=object),
#  'ITGAX': array(['HOXB3', 'HOXC4', 'LBX1', 'MEOX1', 'MEOX2', 'NKX6-1', 'NKX6-2',
#         'NKX6-3', 'NOTO', 'POU6F1(var.2)', 'POU6F2', 'THAP11'],
#        dtype=object),
#  'TGFB1I1': array(['CREM', 'ELF3', 'KLF9', 'PITX1', 'PITX3', 'PRDM4', 'RXRA::VDR',
#         'SRY', 'ZIC1', 'ZIC3', 'ZIC4', 'ZIC5', 'ZKSCAN5'], dtype=object),
#  'ARPC2': array(['FOSL2::JUND(var.2)', 'JUNB(var.2)', 'KLF2', 'KLF6', 'MEF2A',
#         'MEF2B', 'MEF2C', 'MEF2D', 'NEUROG2(var.2)', 'NR2F1', 'NR6A1',
#         'PITX2', 'RARA(var.2)', 'RARA::RXRA', 'RHOXF1', 'SPI1', 'SPIB',
#         'SREBF1(var.2)', 'USF1', 'USF2', 'ZNF135', 'ZNF136', 'ZNF384',
#         'ZNF460'], dtype=object),
#  'PTPN6': array(['BATF3', 'HOXC13', 'NFATC2', 'NR1H4', 'NR2C2(var.2)', 'NR2F1',
#         'SPI1', 'STAT1::STAT2', 'THAP1', 'ZNF263', 'ZNF354C', 'ZNF384'],
#        dtype=object),
#  'BCAR1': array(['GCM1', 'NFATC2', 'SOX15'], dtype=object),
#  'BCAR3': array(['EWSR1-FLI1', 'FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3', 'HOXA6',
#         'HOXB7', 'IRF1', 'MEIS1(var.2)', 'NEUROD1', 'NEUROG2(var.2)',
#         'REST', 'SPI1', 'SPIB', 'ZNF317', 'ZNF354C'], dtype=object),
#  'PVR': array(['HNF4A', 'NHLH1', 'SOX10', 'SREBF1'], dtype=object),
#  'EZR': array(['EWSR1-FLI1', 'FOXC1', 'FOXC2', 'FOXD2', 'HNF1A', 'KLF4',
#         'ONECUT1', 'ONECUT3', 'RUNX3', 'SPI1', 'ZNF135', 'ZNF24', 'ZNF460'],
#        dtype=object),
#  'CALR': array(['EWSR1-FLI1', 'KLF14', 'KLF2', 'KLF3', 'MAFF', 'MAFG', 'SOX10',
#         'SOX4', 'SP1', 'SP2', 'SP3', 'SP4', 'SP9', 'TFAP2A',
#         'TFAP2C(var.2)', 'VDR', 'ZNF354C', 'ZNF460'], dtype=object),
#  'CAPN2': array(['E2F7', 'FOXP2', 'GATA4', 'GRHL2', 'MAZ', 'NFATC2', 'NFATC4',
#         'OTX2', 'PITX1', 'PITX2', 'PITX3', 'SOX10', 'ZKSCAN5', 'ZNF148',
#         'ZNF384'], dtype=object),
#  'CAV1': array(['IKZF1', 'NFYC', 'PKNOX2', 'SOX10', 'SOX14', 'SOX8', 'SOX9',
#         'TGIF1', 'TGIF2', 'TGIF2LX', 'TGIF2LY', 'ZNF354C'], dtype=object),
#  'ITGA7': array(['GATA5', 'IRF7', 'MSANTD3', 'ZNF135', 'ZNF384', 'ZNF460'],
#        dtype=object),
#  'CD151': array(['ELF1', 'ELF3', 'NFE2L1', 'NFIB', 'NR1I3', 'SMAD2::SMAD3::SMAD4',
#         'TFAP2A', 'ZEB1', 'ZNF140'], dtype=object),
#  'ITGA3': array(['ATF4', 'BACH2(var.2)', 'E2F7', 'ESR1', 'EWSR1-FLI1', 'HIC2',
#         'JUN', 'MEIS1', 'MEIS3', 'ZNF135', 'ZNF24', 'ZNF354C'],
#        dtype=object),
#  'CSK': array(['EBF3', 'HNF4A', 'HNF4G', 'LEF1', 'MEF2A', 'NFATC2', 'PBX3',
#         'PRDM1', 'RBPJ', 'TEAD1', 'TEAD2', 'TEAD3', 'TEAD4', 'ZNF135',
#         'ZNF354C', 'ZNF460'], dtype=object),
#  'RHOA': array(['EWSR1-FLI1', 'MAZ', 'MEF2A', 'MEF2C', 'MEIS1', 'MEIS2', 'NFIB',
#         'NFIC(var.2)', 'NFIC::TLX1', 'NFIX(var.2)', 'POU2F2', 'POU2F3',
#         'POU3F4', 'TFAP2A', 'TFAP2C(var.2)', 'ZBTB12', 'ZNF148'],
#        dtype=object),
#  'SDC4': array(['ASCL1', 'IRF1', 'MAZ', 'MYOG', 'ONECUT1', 'PRDM1', 'SIX1',
#         'SREBF1', 'THRB(var.2)', 'ZNF148', 'ZNF263'], dtype=object),
#  'NEXN': array(['BATF', 'BATF::JUN', 'DLX6', 'EBF1', 'FOS', 'FOSL1::JUN',
#         'FOSL1::JUNB', 'FOSL2', 'HOXC13', 'NFATC2', 'NFATC3', 'NFATC4',
#         'NFIC::TLX1', 'PLAG1', 'RBPJ', 'RFX1', 'RFX3', 'SREBF1', 'SREBF2',
#         'TCF7', 'TCF7L2', 'ZKSCAN5', 'ZNF384'], dtype=object),
#  'FERMT3': array(['ASCL1(var.2)', 'EBF1', 'EHF', 'ETV1', 'FOXN3', 'GABPA', 'IKZF1',
#         'IRF1', 'IRF4', 'IRF7', 'IRF8', 'IRF9', 'KLF17', 'SNAI1', 'SPI1',
#         'SPIB', 'SPIC', 'STAT1::STAT2', 'TCF4'], dtype=object),
#  'DNM2': array(['BACH2(var.2)', 'ESRRA', 'ESRRB', 'FOXC2', 'INSM1', 'MEF2A',
#         'POU4F1', 'POU4F3', 'RARA', 'SMAD2::SMAD3::SMAD4', 'SNAI2',
#         'TEAD1', 'ZNF135', 'ZNF460', 'ZNF684'], dtype=object),
#  'CFL1': array(['EGR4', 'FOXF2', 'FOXG1', 'FOXI1', 'FOXK1', 'FOXK2', 'FOXL1',
#         'FOXN3', 'FOXO3', 'FOXO4', 'FOXO6', 'FOXP1', 'FOXP2', 'FOXP3',
#         'IRF1', 'IRF2', 'IRF3', 'IRF7', 'IRF8', 'MAFG', 'MEF2A', 'MEF2B',
#         'MEF2D', 'NKX2-5', 'STAT1::STAT2', 'VDR', 'ZNF282', 'ZNF354C',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'LIMK1': array(['ESRRA', 'ESRRB', 'FOXF2', 'FOXG1', 'FOXI1', 'FOXL1', 'FOXN3',
#         'FOXO3', 'FOXO4', 'FOXO6', 'FOXP3', 'GLI2', 'MGA', 'NR5A1',
#         'PLAG1', 'RBPJ', 'SMAD2::SMAD3::SMAD4', 'SNAI2', 'TBX1', 'TBX15',
#         'TBX4', 'TBX5', 'ZNF135', 'ZNF354C', 'ZNF384', 'ZNF460'],
#        dtype=object),
#  'ENAH': array(['GATA2', 'GATA3', 'GATA6', 'HOXC4', 'MEIS1', 'NR1I2', 'PRDM1',
#         'RXRA::VDR', 'SOX10', 'SREBF1', 'TEAD1', 'THRB(var.3)', 'ZNF135',
#         'ZNF16', 'ZNF354C', 'ZNF460'], dtype=object),
#  'PTPRH': array(['BHLHA15(var.2)', 'CDX2', 'CTCFL', 'CUX1', 'CUX2', 'DUX4', 'DUXA',
#         'HNF1A', 'HNF1B', 'HOXB13', 'IRF1', 'MSC', 'MYF6', 'ONECUT1',
#         'ONECUT2', 'ONECUT3', 'PAX7', 'PHOX2B', 'POU4F1', 'POU4F2',
#         'POU4F3', 'PRDM4', 'PROP1', 'TAL1::TCF3', 'TFAP4', 'ZNF135',
#         'ZNF263', 'ZNF384'], dtype=object),
#  'ITGA11': array(['KLF9', 'MAFK', 'NR1D1', 'NR1H4::RXRA', 'RARB(var.3)',
#         'RARG(var.3)', 'RXRB(var.2)', 'RXRG(var.2)', 'SMAD2::SMAD3::SMAD4',
#         'TFAP2A', 'ZBTB6', 'ZNF143'], dtype=object),
#  'VASP': array(['FOXC1', 'FOXC2', 'HOXC10', 'HOXD10', 'NFATC2', 'NR2F1', 'ONECUT1',
#         'ONECUT3', 'RREB1', 'ZNF384'], dtype=object),
#  'FYN': array(['ATF6', 'BATF', 'BATF3', 'BATF::JUN', 'CDX2', 'CREB3L1',
#         'FOS::JUN', 'FOS::JUNB', 'FOS::JUND', 'FOSB::JUNB', 'FOSL1::JUN',
#         'FOSL1::JUNB', 'FOSL1::JUND', 'FOSL2::JUN', 'FOSL2::JUNB',
#         'GATA1::TAL1', 'IRF1', 'IRF3', 'IRF8', 'IRF9', 'MAF', 'MAFA',
#         'STAT1::STAT2', 'ZNF684'], dtype=object),
#  'GAB1': array(['NFATC2', 'NFIX', 'RARA(var.2)', 'RARA::RXRG', 'RBPJ', 'STAT1',
#         'STAT3', 'TFAP2B(var.2)'], dtype=object),
#  'GNB2L1': array(['MZF1(var.2)', 'NFIL3', 'NFYA', 'NFYC', 'THAP11', 'YY1', 'YY2',
#         'ZFP42', 'ZNF528'], dtype=object),
#  'PLEC': array(['ASCL1', 'KLF17', 'MAFF', 'MSGN1', 'MYOG', 'NR1H2::RXRA', 'NR2C2',
#         'NR2F1(var.2)', 'PHOX2B', 'PPARA::RXRA', 'PPARD', 'RXRB', 'RXRG',
#         'THRB', 'ZNF317', 'ZNF682'], dtype=object),
#  'SHARPIN': array(['MYB', 'NR3C1', 'NR3C2', 'NRF1', 'PROX1', 'SNAI3', 'TCF3',
#         'ZBTB18', 'ZEB1'], dtype=object),
#  'ITGB1BP1': array(['ATF2', 'ATF4', 'CEBPG(var.2)', 'EHF', 'FOS::JUND', 'FOSL1::JUN',
#         'FOSL1::JUNB', 'FOSL1::JUND(var.2)', 'FOSL2', 'FOSL2::JUN',
#         'HOXC4', 'IRF1', 'MEF2A', 'MZF1', 'NFKB1', 'NR1D1', 'NR1D2',
#         'NR2C2(var.2)', 'PITX1', 'RARA', 'RXRG(var.2)', 'SPI1', 'SPIB',
#         'STAT1::STAT2', 'ZNF135', 'ZNF460'], dtype=object),
#  'GRB7': array(['BARX1', 'EGR2', 'EWSR1-FLI1', 'MZF1', 'NFKB1', 'NFKB2', 'NFYB',
#         'NR4A2', 'PRDM4', 'REL', 'RELA', 'RELB', 'ZBTB7A'], dtype=object),
#  'CRK': array(['EBF1', 'FOXD2', 'KLF15', 'NKX2-5', 'RREB1', 'SP9', 'ZNF148',
#         'ZNF740'], dtype=object),
#  'IRS1': array(['ATF4', 'DUX4', 'EHF', 'IKZF1', 'IRF8', 'JUN::JUNB', 'MEIS1',
#         'PHOX2A', 'SOHLH2', 'STAT1::STAT2', 'TCFL5', 'ZNF16', 'ZNF24',
#         'ZNF460'], dtype=object),
#  'ITGA4': array(['ESR1', 'EVX1', 'HOXA4', 'KLF2', 'KLF4', 'KLF5', 'NFATC2', 'PAX1',
#         'PAX6', 'PAX9', 'SP2', 'ZNF528'], dtype=object),
#  'ITGA8': array(['E2F1', 'E2F3', 'E2F4', 'MEIS1', 'RARG(var.3)', 'SPI1', 'ZBTB12'],
#        dtype=object),
#  'ITGAV': array(['ASCL1(var.2)', 'HOXB6', 'LHX5', 'MNX1', 'NKX6-1', 'STAT1::STAT2',
#         'TCF4', 'VSX1', 'ZBTB6', 'ZEB1', 'ZNF135', 'ZNF460'], dtype=object),
#  'ITGB6': array(['BCL6B', 'EOMES', 'FOS', 'FOS::JUN', 'FOS::JUND', 'FOSB::JUNB',
#         'FOSL1', 'FOSL1::JUN', 'FOSL1::JUNB', 'FOSL1::JUND', 'FOSL2',
#         'FOSL2::JUN', 'FOSL2::JUNB', 'FOSL2::JUND', 'JUN(var.2)', 'JUNB',
#         'JUND', 'MGA', 'NFE2', 'NFIB', 'NFIC(var.2)', 'NFIC::TLX1',
#         'NFIX(var.2)', 'RARA(var.2)', 'RARA::RXRA', 'RARA::RXRG', 'SPIC',
#         'STAT1', 'STAT3', 'TBX1', 'TBX15', 'TBX20', 'TBX21', 'TBX3',
#         'TBX4', 'TBX5', 'TBX6', 'TFAP2A', 'TFAP2A(var.2)', 'TFAP2B',
#         'TFAP2C', 'VDR', 'ZNF136'], dtype=object),
#  'ITGB8': array(['ATF2', 'KLF17', 'LMX1A', 'MEF2A', 'NFATC2', 'NFYB',
#         'NR2F1(var.2)', 'RARB(var.3)', 'RARG(var.3)', 'RXRG(var.2)',
#         'SOX13', 'SOX9', 'SREBF1(var.2)', 'USF1', 'USF2'], dtype=object),
#  'SHC1': array(['CTCF', 'EHF', 'EWSR1-FLI1', 'FOXA1', 'IKZF1', 'KLF5', 'PBX3',
#         'PKNOX1', 'RFX2', 'RFX4', 'RFX5', 'SPI1', 'SPIB', 'THAP1'],
#        dtype=object),
#  'KEAP1': array(['EBF1', 'EBF3', 'FOXH1', 'HAND2', 'HOXA6', 'HOXB6', 'LHX5',
#         'NKX6-1', 'PLAG1', 'PROX1', 'SMAD3', 'SMAD5', 'TEAD1', 'TEAD2',
#         'TEAD4', 'ZNF684'], dtype=object),
#  'TENC1': array(['DLX6', 'GFI1', 'HNF4G', 'NFATC2', 'NR3C1', 'NR3C2', 'RORA',
#         'SIX1', 'SIX2', 'ZNF384'], dtype=object),
#  'LASP1': array(['EBF1', 'EBF3', 'MEF2C', 'NFATC2', 'PAX9', 'PITX2', 'RHOXF1',
#         'SREBF1', 'SREBF2', 'ZNF135', 'ZNF354C', 'ZNF384', 'ZNF449',
#         'ZNF460'], dtype=object),
#  'SH2B1': array(['FERD3L', 'NR1H2::RXRA', 'NR1I2', 'NR2C2', 'NR2F1', 'NR2F1(var.2)',
#         'NR2F2', 'NR4A1', 'NR5A1', 'PLAG1', 'PPARA::RXRA', 'PPARD', 'RBPJ',
#         'RXRA::VDR', 'RXRB', 'RXRG', 'SP2', 'THRB', 'THRB(var.2)',
#         'ZNF148', 'ZNF528', 'ZNF682', 'ZNF684'], dtype=object),
#  'LIMS1': array(['ARNT::HIF1A', 'FOXA2', 'FOXD2', 'FOXE1', 'FOXI1', 'FOXK2',
#         'FOXL1', 'FOXO4', 'FOXO6', 'FOXP1', 'FOXP2', 'FOXP3', 'GRHL2',
#         'ISX', 'LBX1', 'LHX9', 'NFIC', 'NKX6-2', 'PRRX1', 'PRRX2', 'RREB1',
#         'UNCX'], dtype=object),
#  'LIMS2': array(['MYB', 'ZBTB6', 'ZNF135', 'ZNF354C', 'ZNF384', 'ZNF460'],
#        dtype=object),
#  'MMP14': array(['CDX2', 'HOXA10', 'HOXD9', 'MAFK', 'MEF2A', 'NFATC2',
#         'NR2C2(var.2)', 'PRDM1', 'VEZF1', 'ZBTB6', 'ZNF135', 'ZNF354C',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'MACF1': array(['EGR1', 'ETV1', 'IKZF1', 'KLF15', 'KLF5', 'MYOD1', 'OSR2',
#         'POU2F3', 'POU5F1', 'REL', 'SMAD2::SMAD3::SMAD4', 'SOX15', 'SPI1',
#         'ZBTB26', 'ZNF263'], dtype=object),
#  'PIP5K1C': array(['CTCF', 'ELK1', 'ERF', 'ERG', 'ETS1', 'ETS2', 'FLI1', 'IRF4',
#         'IRF7', 'IRF8', 'IRF9', 'MSANTD3', 'NFATC2', 'PHOX2B', 'POU1F1',
#         'POU4F1', 'POU4F3', 'POU6F1(var.2)', 'STAT3', 'THAP11', 'ZBTB14',
#         'ZBTB33', 'ZNF528'], dtype=object),
#  'PFN1': array(['BCL6', 'KLF2', 'KLF6', 'KLF9', 'MAFG', 'MEF2A', 'MYF6',
#         'SREBF1(var.2)', 'STAT1::STAT2', 'THAP11', 'ZNF135', 'ZNF140',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'NF2': array(['CEBPG(var.2)', 'DUX4', 'DUXA', 'EHF', 'ELF1', 'ELF3', 'ETV1',
#         'ETV4', 'GABPA', 'IKZF1', 'MYF5', 'NFIA', 'NFIB', 'NFIX', 'PHOX2B',
#         'POU2F2', 'RORB', 'SPIB', 'STAT3', 'YY1', 'ZFP42', 'ZNF384'],
#        dtype=object),
#  'CIB1': array(['EWSR1-FLI1', 'GFI1', 'LEF1', 'MAX', 'MAX::MYC', 'MGA', 'TBX1',
#         'TBX15', 'TBX20', 'TBX4', 'TBX5', 'TCF7', 'TCF7L2', 'ZBTB6',
#         'ZNF135', 'ZNF460'], dtype=object),
#  'NRP1': array(['E2F7', 'E2F8', 'EWSR1-FLI1', 'GRHL2', 'HNF4A', 'HNF4A(var.2)',
#         'HNF4G', 'KLF9', 'NR2F1', 'NR2F1(var.3)', 'NR2F2', 'NR4A1',
#         'NR4A2', 'RARA', 'SP8', 'STAT1', 'STAT3', 'ZSCAN4'], dtype=object),
#  'SDCBP': array(['E2F6', 'E2F7', 'E2F8', 'FIGLA', 'GATA4', 'GATA5', 'MEF2A',
#         'MEF2C', 'NFATC2', 'SOX12', 'SOX14', 'TFDP1', 'ZNF135', 'ZNF354C',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'ITGAE': array(['BACH2(var.2)', 'BATF', 'BATF3', 'BATF::JUN', 'DUX4', 'HNF4A',
#         'HNF4G', 'KLF17', 'KLF4', 'KLF9', 'NR2F2', 'NR4A1', 'RORA',
#         'RREB1', 'SPIC'], dtype=object),
#  'PABPC1': array(['BACH1', 'DLX5', 'FOSL2', 'FOXI1', 'FOXL1', 'FOXN3', 'FOXO4',
#         'FOXO6', 'FOXP3', 'HOXA7', 'HOXB8', 'HOXD8', 'JUN(var.2)', 'KLF13',
#         'KLF14', 'KLF4', 'LHX1', 'MEF2A', 'MEF2B', 'MEF2C', 'MEF2D',
#         'NFE2L1', 'NFYA', 'NFYC', 'NR4A1', 'PLAG1', 'SOX10', 'SOX4',
#         'ZNF135'], dtype=object),
#  'PAK1': array(['ATF2', 'ATF3', 'ATF7', 'BACH2(var.2)', 'CREB3L4(var.2)', 'CREM',
#         'FOS::JUN(var.2)', 'FOSB::JUN', 'FOSB::JUNB(var.2)',
#         'FOSL1::JUN(var.2)', 'FOSL1::JUND(var.2)', 'FOSL2::JUN(var.2)',
#         'FOSL2::JUNB(var.2)', 'FOSL2::JUND(var.2)', 'FOXN3', 'JDP2(var.2)',
#         'JUN', 'JUN::JUNB(var.2)', 'JUNB(var.2)', 'JUND(var.2)', 'KLF15',
#         'MAZ', 'NFKB1', 'NR2C2', 'PRDM1', 'SOX10', 'SPI1', 'ZEB1',
#         'ZNF148', 'ZNF263', 'ZNF75D'], dtype=object),
#  'PARVB': array(['GLIS1', 'HNF1A', 'NHLH1', 'PBX3', 'RARA(var.2)', 'SOX13', 'SOX15',
#         'SOX9', 'ZNF24'], dtype=object),
#  'ABI1': array(['INSM1', 'KLF10', 'KLF11', 'KLF16', 'KLF17', 'KLF2', 'KLF4',
#         'KLF5', 'KLF6', 'KLF9', 'NFYA', 'NFYC', 'NKX6-3', 'POU6F2',
#         'RREB1', 'SP1', 'SP3', 'SP4', 'SP8'], dtype=object),
#  'ITGA1': array(['DLX6', 'GATA2', 'GATA3', 'GATA6', 'HOXB4', 'HOXC10', 'HOXD4',
#         'NFATC2', 'NFIC', 'SOX13', 'SOX2', 'SRY', 'TCF7L2', 'TEAD2',
#         'TP53', 'TP73'], dtype=object),
#  'CORO1B': array(['BHLHE22(var.2)', 'FOXH1', 'GFI1', 'HOXC10', 'IRF6', 'KLF4',
#         'NRF1', 'PHOX2A', 'RFX1', 'RFX2', 'RFX3', 'RFX4', 'RFX5', 'SOX13',
#         'ZNF24', 'ZNF354C'], dtype=object),
#  'PPM1M': array(['BACH1', 'KLF15', 'LEF1', 'MAF', 'MAF::NFE2', 'MAFA', 'MAFK',
#         'NFE2L1', 'NKX6-3', 'NR2C2', 'PRDM1', 'SOX10', 'SOX4', 'TCF7L2',
#         'ZNF354C', 'ZNF382'], dtype=object),
#  'PRNP': array(['ASCL1(var.2)', 'FOXC2', 'FOXD2', 'FOXE1', 'IRF1', 'MEF2C', 'MGA',
#         'MYF5', 'REL', 'RELA', 'RORA', 'RORA(var.2)', 'RORC', 'SNAI2',
#         'SNAI3', 'TBR1', 'TBX1', 'TBX15', 'TBX18', 'TBX21', 'TBX4', 'TBX5',
#         'TBX6', 'TCF12(var.2)', 'TCF4', 'THAP11', 'ZNF135', 'ZNF384',
#         'ZNF460'], dtype=object),
#  'PTK2B': array(['ELF3', 'IKZF1', 'INSM1', 'KLF9', 'MSANTD3', 'NFATC2', 'RREB1',
#         'SPI1', 'SPIB', 'ZBTB14', 'ZNF354C'], dtype=object),
#  'STAT3': array(['GATA3', 'GLI2', 'GLI3', 'GLIS3', 'GRHL1', 'KLF13', 'KLF4',
#         'MSANTD3', 'NFATC2', 'NFIC', 'NKX2-5', 'POU6F1(var.2)', 'TFCP2',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'RAC1': array(['ASCL1(var.2)', 'EOMES', 'HOXA10', 'HOXB6', 'HOXD9', 'IRF1',
#         'KLF15', 'KLF5', 'MYOG', 'NFIA', 'NFIC', 'NHLH1', 'NHLH2',
#         'NKX6-3', 'NR1H2::RXRA', 'RARA', 'REST', 'SP1', 'SP2', 'SP4',
#         'TBR1', 'TBX2', 'TBX20', 'TBX21', 'TCF4'], dtype=object),
#  'RAPGEF1': array(['ASCL1', 'BATF3', 'BHLHE22(var.2)', 'EHF', 'ELF1', 'EWSR1-FLI1',
#         'FOXE1', 'HES6', 'HNF4A', 'HNF4G', 'JUN(var.2)', 'KLF10', 'NHLH1',
#         'RARA', 'RREB1', 'SOX15', 'SP8', 'SPI1', 'SPIC', 'VDR', 'ZNF24'],
#        dtype=object),
#  'RASA1': array(['PBX1', 'PRDM1', 'SP1', 'SP4', 'ZNF274', 'ZNF354C'], dtype=object),
#  'TESK1': array(['BARHL1', 'ETV1', 'ETV4', 'EWSR1-FLI1', 'FOXC2', 'FOXE1', 'FOXN3',
#         'GABPA', 'GLIS2', 'GSC', 'GSC2', 'MZF1', 'NR1H2::RXRA',
#         'NR2F1(var.2)', 'OTX2', 'PHOX2B', 'PITX1', 'PPARD', 'RARA::RXRA',
#         'RBPJ', 'RXRB', 'RXRG', 'THRB', 'VDR', 'ZKSCAN5', 'ZNF652'],
#        dtype=object),
#  'DEF6': array(['ETV1', 'GLIS1', 'IRF1', 'IRF3', 'IRF4', 'IRF5', 'IRF8', 'IRF9',
#         'NFATC2', 'SPI1', 'SPIB', 'STAT1::STAT2', 'YY1', 'ZBTB12', 'ZFP42',
#         'ZFP57'], dtype=object),
#  'ITGAL': array(['ATOH1(var.2)', 'BHLHA15(var.2)', 'MYOD1', 'NFATC2', 'RARA',
#         'REST', 'RREB1', 'ZNF135', 'ZNF24', 'ZNF341', 'ZNF354C', 'ZNF384',
#         'ZNF449', 'ZNF460'], dtype=object),
#  'ENG': array(['ERG', 'ETS1', 'ETV3', 'FEV', 'IRF3', 'LEF1', 'MAZ', 'POU1F1',
#         'POU2F2', 'POU2F3', 'POU3F1', 'POU5F1', 'RORC', 'SOX10', 'SOX18',
#         'SOX4', 'SP9', 'SPDEF', 'STAT1::STAT2', 'THAP11', 'ZNF460'],
#        dtype=object),
#  'LAYN': array(['FERD3L', 'FOXG1', 'FOXI1', 'FOXL1', 'FOXN3', 'FOXO3', 'FOXO4',
#         'FOXO6', 'FOXP3', 'IRF7', 'ISL2', 'MSC', 'NEUROD1',
#         'NEUROG2(var.2)', 'NR2C2', 'NR2F2', 'RARB(var.3)', 'RORA',
#         'RXRB(var.2)', 'ZNF136', 'ZNF460'], dtype=object),
#  'SIRPA': array(['CDX2', 'HOXB13', 'KLF10', 'KLF11', 'KLF14', 'KLF16', 'KLF2',
#         'KLF3', 'KLF5', 'KLF6', 'KLF9', 'SP1', 'SP3', 'SP4', 'SP9',
#         'STAT1::STAT2', 'ZNF24'], dtype=object),
#  'SLC3A2': array(['ASCL1(var.2)', 'KLF9', 'MAZ', 'NR6A1', 'RFX1', 'SNAI1', 'SNAI3',
#         'STAT1', 'STAT3', 'TCF4', 'TFAP2A', 'TFAP2C(var.2)', 'TFAP2E',
#         'TWIST1', 'ZBTB18', 'ZNF148', 'ZNF263'], dtype=object),
#  'SORBS1': array(['BCL6', 'ETV4', 'FOXD1', 'FOXI1', 'FOXL1', 'FOXN3', 'FOXO4',
#         'FOXO6', 'FOXP3', 'IKZF1', 'ZNF384'], dtype=object),
#  'SORBS2': array(['EWSR1-FLI1', 'HES5', 'HES7', 'MEF2A', 'NFATC2', 'POU6F1(var.2)',
#         'RARA', 'TP73', 'ZNF135', 'ZNF384', 'ZNF460'], dtype=object),
#  'SORBS3': array(['EWSR1-FLI1', 'MZF1', 'PBX2', 'ZSCAN4'], dtype=object),
#  'SRCIN1': array(['EHF', 'ELF1', 'ELF3', 'ELF4', 'ELF5', 'ETV1', 'EWSR1-FLI1',
#         'FOXA2', 'FOXN3', 'GABPA', 'GRHL1', 'PBX3', 'TFCP2', 'ZBTB26',
#         'ZBTB7A', 'ZNF354C'], dtype=object),
#  'STARD13': array(['EHF', 'ELF3', 'MEIS1', 'SPI1', 'SPIC', 'ZNF136'], dtype=object),
#  'LRP1': array(['HAND2', 'IRF1', 'IRF7', 'MAZ', 'SOX10', 'TFAP2A(var.2)', 'TFAP2B',
#         'TFAP2C', 'ZNF148', 'ZNF263', 'ZNF282', 'ZNF354C', 'ZNF384'],
#        dtype=object),
#  'CAPN1': array(['EWSR1-FLI1', 'MAFK', 'MEF2A', 'POU2F2', 'RARA(var.2)',
#         'RARA::RXRG', 'SREBF1(var.2)', 'TBX18', 'TBX2', 'TBX3', 'THAP11',
#         'ZNF135', 'ZNF143', 'ZNF384', 'ZNF460'], dtype=object),
#  'TES': array(['IRF1', 'PPARA::RXRA', 'ZNF682'], dtype=object),
#  'THY1': array(['MEIS1', 'MEIS2', 'OSR2', 'SREBF1(var.2)', 'STAT1::STAT2'],
#        dtype=object),
#  'TNS1': array(['CEBPD', 'EWSR1-FLI1', 'FIGLA', 'FOS', 'FOSL1', 'FOSL1::JUND',
#         'FOSL2::JUN(var.2)', 'JUNB', 'JUND', 'MYOD1', 'OSR1', 'REST',
#         'SCRT1', 'SCRT2', 'SOX13', 'SOX9', 'THRB(var.3)'], dtype=object),
#  'TRIO': array(['BARX2', 'CTCF', 'MEIS1', 'MEIS2', 'NR2F1(var.2)', 'POU1F1',
#         'POU2F1', 'POU3F1', 'POU3F2', 'POU3F3', 'POU3F4', 'POU5F1B',
#         'SPIB', 'ZNF682'], dtype=object),
#  'RAVER1': array(['EGR1', 'EGR3', 'KLF15', 'KLF16', 'MAX::MYC', 'MAZ', 'MEF2A',
#         'MYCN', 'MZF1(var.2)', 'NFATC2', 'SOX18', 'TFAP2A',
#         'TFAP2C(var.2)', 'ZBTB6', 'ZNF135', 'ZNF148', 'ZNF282', 'ZNF384',
#         'ZNF460'], dtype=object),
#  'CBL': array(['ATF2', 'BACH1', 'BATF', 'BATF::JUN', 'FOS', 'FOSL1',
#         'FOSL1::JUNB', 'FOXE1', 'GSC', 'GSC2', 'HNF4A', 'HNF4G', 'JUN',
#         'JUN(var.2)', 'JUNB', 'JUND', 'MAF', 'MAF::NFE2', 'MAFA', 'MAFK',
#         'MITF', 'NFE2L1', 'NFIB', 'NR2C2(var.2)', 'NR2F1', 'NR4A2', 'PBX3',
#         'PITX1', 'RARG(var.3)', 'RXRB(var.2)', 'TFEB', 'THRB(var.2)',
#         'USF1', 'USF2', 'ZBTB18'], dtype=object),
#  'ITGB4': array(['BARX2', 'EGR3', 'FOXN3', 'FOXP2', 'HNF1A', 'HOXA13', 'KLF5',
#         'MLX', 'NFYA', 'NFYC', 'SPIB', 'STAT3', 'TFE3', 'TFEB', 'TFEC',
#         'THAP11', 'ZNF140', 'ZNF24', 'ZNF354C'], dtype=object),
#  'HSPA2': array(['ESR2', 'GLIS2', 'GRHL2', 'KLF16', 'KLF4', 'KLF5', 'POU1F1',
#         'POU2F1', 'POU2F2', 'POU2F3', 'POU3F1', 'POU3F2', 'POU3F3',
#         'POU3F4', 'POU5F1', 'POU5F1B', 'RFX1', 'RFX3', 'RFX4', 'RFX7',
#         'SRF', 'TFAP2A(var.3)', 'TFAP2B(var.3)', 'TFAP2C(var.3)',
#         'ZNF354C', 'ZNF684'], dtype=object),
#  'RDX': array(['CEBPA', 'CEBPG(var.2)', 'GATA3', 'HLF', 'NFATC2', 'NFIB',
#         'NFIC(var.2)', 'NFIC::TLX1', 'NFIL3', 'NFIX(var.2)', 'NR3C1',
#         'OSR2', 'RELB', 'RREB1', 'SOX12', 'SOX13', 'SOX14', 'SOX9'],
#        dtype=object),
#  'ITGA5': array(['ASCL1(var.2)', 'KLF17', 'LBX2', 'MSX1', 'RARG(var.3)',
#         'RXRB(var.2)', 'RXRG(var.2)', 'SNAI1', 'TCF4', 'TCF7', 'ZNF135',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'ZYX': array(['ATOH1(var.2)', 'BHLHA15(var.2)', 'ELF3', 'GATA5', 'HOXA4',
#         'MEIS1(var.2)', 'MSC', 'MYOG', 'PBX1', 'TWIST1', 'USF1', 'USF2',
#         'ZBTB18', 'ZBTB26', 'ZNF354C', 'ZNF528'], dtype=object),
#  'ARHGAP32': array(['ASCL1(var.2)', 'EBF1', 'EBF3', 'EHF', 'ELF1', 'ELF3', 'ELF4',
#         'ELF5', 'ETV1', 'FOXI1', 'FOXK1', 'FOXL1', 'FOXO4', 'FOXO6',
#         'FOXP3', 'GABPA', 'IKZF1', 'MAZ', 'PITX2', 'RHOXF1', 'TCF4',
#         'TFAP2B(var.2)', 'TFAP4', 'ZBTB7A', 'ZNF148', 'ZNF528'],
#        dtype=object),
#  'ARHGAP5': array(['ATOH7', 'BHLHE22', 'BHLHE23', 'DUXA', 'NEUROG1', 'NEUROG2',
#         'OLIG1', 'OLIG2', 'OLIG3', 'OTX2', 'PITX1', 'RARA', 'TFAP4(var.2)',
#         'YY1', 'ZFP42', 'ZNF384', 'ZNF682'], dtype=object),
#  'ASAP2': array(['DLX5', 'EWSR1-FLI1', 'FIGLA', 'FOXA3', 'FOXI1', 'FOXK2', 'FOXL1',
#         'FOXO4', 'FOXO6', 'FOXP1', 'FOXP2', 'FOXP3', 'HOXA7', 'HOXB8',
#         'HOXD8', 'LHX1', 'MTF1', 'NFATC2', 'POU2F1', 'POU2F2', 'POU2F3',
#         'POU3F1', 'POU3F2', 'POU3F3', 'POU3F4', 'POU5F1', 'POU5F1B',
#         'TEAD1', 'TEAD3', 'TEAD4', 'ZIC1', 'ZIC4', 'ZIC5', 'ZNF384'],
#        dtype=object),
#  'PTEN': array(['ETV1', 'ETV4', 'GABPA', 'HLF', 'HOXC4', 'LMX1A', 'OSR1', 'OSR2',
#         'OTX1', 'SPIB', 'STAT1', 'TEAD1', 'TEF', 'ZNF16', 'ZNF274'],
#        dtype=object),
#  'PKD1': array(['FOXA2', 'FOXB1', 'FOXC1', 'FOXC2', 'FOXD2', 'FOXN3', 'GSC',
#         'GSC2', 'HNF1A', 'HNF1B', 'HOXB13', 'MAFF', 'MEF2D',
#         'MEIS1(var.2)', 'NFIC(var.2)', 'NFIX(var.2)', 'NFYA', 'NFYB',
#         'NFYC', 'NR1H2::RXRA', 'NRL', 'ONECUT1', 'PAX3', 'PAX7', 'PBX2',
#         'PHOX2B', 'PITX1', 'PITX3', 'POU1F1', 'POU3F3', 'POU4F1', 'POU4F2',
#         'POU4F3', 'PPARG', 'PROP1', 'ZBTB12', 'ZNF460'], dtype=object),
#  'CASP8': array(['BHLHE22(var.2)', 'CREB1', 'FIGLA', 'GATA1', 'LMX1A', 'MZF1',
#         'NHLH1', 'NHLH2', 'RBPJ', 'SCRT1', 'SIX1', 'ZNF460'], dtype=object),
#  'ASAP3': array(['HOXC4', 'INSM1', 'IRF1', 'KLF14', 'KLF15', 'KLF16', 'KLF2',
#         'KLF4', 'KLF5', 'MYF5', 'PRDM1', 'SP1', 'SP2', 'SP3', 'SP4', 'SP8',
#         'SP9', 'STAT1', 'ZNF148', 'ZNF384', 'ZNF682', 'ZNF740'],
#        dtype=object),
#  'ITGB3BP': array(['MGA', 'NFIB', 'NFIC::TLX1', 'SMAD2::SMAD3::SMAD4', 'SNAI2',
#         'TBX1', 'TBX15', 'TBX4', 'TBX5', 'ZBTB6', 'ZKSCAN5', 'ZNF135',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'RNF5': array(['GRHL1', 'MAF::NFE2', 'MSANTD3', 'NFATC2', 'NFE2L1', 'PLAGL2',
#         'RARA(var.2)', 'SPI1', 'SPIB', 'TFCP2', 'ZKSCAN5', 'ZNF354C'],
#        dtype=object),
#  'ITGAM': array(['HOXB6', 'HSF4', 'LHX5', 'MNX1', 'NFATC2', 'NKX6-1', 'OSR1',
#         'POU1F1', 'POU2F1', 'POU2F2', 'POU2F3', 'POU3F1', 'POU3F2',
#         'POU3F3', 'POU5F1', 'RELA', 'RFX1', 'RFX3', 'RFX7', 'SP8',
#         'ZNF682'], dtype=object),
#  'ITGB1': array(['ESR1', 'MEF2A', 'SREBF1(var.2)', 'VDR', 'YY1', 'ZNF135', 'ZNF263',
#         'ZNF354C', 'ZNF384', 'ZNF460'], dtype=object),
#  'ITGB2': array(['ASCL1', 'BHLHE22(var.2)', 'FOXF2', 'FOXN3', 'HNF4A(var.2)',
#         'IRF1', 'MEF2A', 'MEF2B', 'MEF2C', 'MEF2D', 'NFATC2', 'NFIA',
#         'NHLH1', 'NKX2-2', 'POU3F4', 'PROP1', 'SNAI2', 'ZNF354C', 'ZNF384'],
#        dtype=object),
#  'LPP': array(['ELF1', 'ELF3', 'MEIS1', 'MEIS2', 'NFIB', 'NFYB', 'OSR2', 'ZNF274'],
#        dtype=object),
#  'GRB2': array(['FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3', 'GATA2', 'GATA3',
#         'GATA4', 'GATA6', 'HOXD11', 'IKZF1', 'IRF1', 'MEF2A', 'MEF2C',
#         'MEIS1', 'PPARA::RXRA', 'PRDM4', 'RARA::RXRA', 'SRY', 'STAT3',
#         'USF1', 'USF2', 'ZNF449'], dtype=object),
#  'ITGB5': array(['CDX2', 'HOXB4', 'HOXD4', 'MXI1', 'REST', 'RREB1', 'TFAP2A(var.3)',
#         'TFAP2B(var.3)', 'TFAP2C(var.3)', 'TFAP4', 'THAP11', 'YY1', 'YY2',
#         'ZBTB6', 'ZFP42', 'ZNF317', 'ZNF384', 'ZNF460'], dtype=object),
#  'MYH9': array(['ATOH1(var.2)', 'BACH1', 'BATF', 'BATF3', 'BATF::JUN', 'EHF',
#         'ELF1', 'ELF3', 'ETV1', 'ETV4', 'FOS', 'GABPA', 'IKZF1',
#         'MAF::NFE2', 'MAFK', 'PKNOX2', 'PPARG', 'RBPJ', 'RXRA::VDR',
#         'SPI1', 'SPIB', 'SPIC', 'TGIF1', 'TGIF2', 'TGIF2LX', 'TGIF2LY',
#         'ZNF135', 'ZNF652'], dtype=object),
#  'NRP2': array(['E2F6', 'FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3', 'ISL2',
#         'SOX18', 'ZNF449', 'ZSCAN29'], dtype=object),
#  'PALLD': array(['BARX1', 'ISX', 'LBX1', 'LHX9', 'NKX6-2', 'PRRX1', 'PRRX2', 'SIX1',
#         'SIX2', 'STAT1', 'STAT3', 'TCF7L1', 'UNCX', 'ZNF354C'],
#        dtype=object),
#  'CSRP1': array(['ATOH7', 'BHLHE22', 'BHLHE23', 'FOXC2', 'NEUROG1', 'NEUROG2',
#         'NFATC2', 'NFIC::TLX1', 'NKX6-3', 'OLIG1', 'OLIG2', 'OLIG3',
#         'POU1F1', 'POU2F1', 'POU2F2', 'POU2F3', 'POU3F1', 'POU3F2',
#         'POU3F3', 'POU3F4', 'POU4F1', 'POU4F2', 'POU4F3', 'POU5F1',
#         'POU5F1B', 'RARA', 'RXRA::VDR', 'TAL1::TCF3', 'TFAP4(var.2)',
#         'ZNF460'], dtype=object),
#  'RNF185': array(['BCL6', 'ELF1', 'ELF3', 'ETV1', 'ETV4', 'FOXA1', 'FOXA2', 'FOXA3',
#         'FOXB1', 'FOXC1', 'FOXC2', 'FOXD1', 'FOXG1', 'FOXI1', 'FOXK1',
#         'FOXK2', 'FOXL1', 'FOXN3', 'FOXO3', 'FOXO4', 'FOXO6', 'FOXP1',
#         'FOXP2', 'FOXP3', 'GABPA', 'GFI1', 'HOXC13', 'IKZF1',
#         'JUND(var.2)', 'NFYB', 'NHLH2', 'ONECUT1', 'PRDM4', 'SOHLH2'],
#        dtype=object),
#  'TUBA1B': array(['DUXA', 'IRF1', 'IRF2', 'KLF11', 'KLF13', 'KLF14', 'KLF16', 'MAF',
#         'NR1I3', 'RELA', 'SP3', 'SP8', 'SP9', 'TFAP2A(var.2)', 'TFAP2B',
#         'TFAP2B(var.2)', 'TFAP2C', 'ZNF135', 'ZNF384', 'ZNF460'],
#        dtype=object),
#  'PTK2': array(['ASCL1(var.2)', 'EWSR1-FLI1', 'GRHL2', 'JUN::JUNB(var.2)', 'LHX2',
#         'LMX1A', 'MEIS2(var.2)', 'NR2C2(var.2)', 'PBX2', 'PRDM4', 'SNAI1',
#         'TCF4', 'TEAD1', 'TEAD2', 'TFAP2B(var.2)', 'ZKSCAN5', 'ZNF382'],
#        dtype=object),
#  'PXN': array(['E2F6', 'FOXA2', 'FOXB1', 'FOXC1', 'FOXC2', 'FOXD2', 'FOXN3',
#         'IRF1', 'KLF17', 'MEF2A', 'MEF2C', 'NFIB', 'ONECUT1', 'POU2F1',
#         'POU2F2', 'POU2F3', 'POU3F1', 'POU3F2', 'POU3F3', 'POU3F4',
#         'POU5F1', 'POU5F1B', 'SOX10', 'SREBF1', 'SREBF2', 'STAT1::STAT2',
#         'ZNF16', 'ZNF384', 'ZNF449', 'ZNF682'], dtype=object),
#  'HRAS': array(['EWSR1-FLI1', 'FOXB1', 'FOXC1', 'FOXC2', 'FOXD2', 'FOXE1', 'FOXO6',
#         'NFIA', 'NFIC', 'NFIX', 'ZKSCAN5', 'ZNF263'], dtype=object),
#  'FABP3': array(['BCL6', 'BCL6B', 'EBF1', 'EBF3', 'ELF3', 'ELF5', 'FERD3L', 'HOXA6',
#         'HOXB6', 'LHX5', 'MEIS1', 'NKX6-1', 'PAX3', 'PAX7', 'RREB1',
#         'SPI1', 'SPIC', 'STAT1', 'ZNF136'], dtype=object),
#  'TRIP6': array(['ETV6', 'MZF1(var.2)', 'SPIC', 'SRF', 'VDR', 'ZKSCAN5'],
#        dtype=object),
#  'CRKL': array(['ARNT::HIF1A', 'ETV4', 'THAP11', 'THRB(var.3)', 'ZNF140'],
#        dtype=object),
#  'HSPB1': array(['BCL6B', 'DLX6', 'JUND(var.2)', 'KLF2', 'KLF6', 'KLF9', 'MGA',
#         'RUNX3', 'SMAD2::SMAD3::SMAD4', 'SNAI2', 'TAL1::TCF3', 'TBX1',
#         'TBX15', 'TBX4', 'TBX5', 'ZBTB26', 'ZNF135', 'ZNF384', 'ZNF460'],
#        dtype=object),
#  'SSH1': array(['ASCL1(var.2)', 'ELF1', 'ELF3', 'FERD3L', 'GABPA', 'HES7', 'IRF1',
#         'MEF2A', 'MXI1', 'NFATC2', 'NFIC(var.2)', 'SNAI1', 'TCF12(var.2)',
#         'TCF3', 'TCF4', 'VSX1', 'ZKSCAN5', 'ZNF354C', 'ZNF460'],
#        dtype=object),
#  'SVIL': array(['BACH1', 'EHF', 'ELF3', 'FERD3L', 'FOS', 'FOS::JUN', 'FOS::JUNB',
#         'FOS::JUND', 'FOSB::JUNB', 'FOSL1', 'FOSL1::JUN', 'FOSL1::JUNB',
#         'FOSL1::JUND', 'FOSL2', 'FOSL2::JUN', 'FOSL2::JUNB', 'FOSL2::JUND',
#         'FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3', 'HOXC4', 'JUN(var.2)',
#         'JUN::JUNB', 'KLF17', 'MAFG', 'MAFK', 'NFKB1', 'NFKB2', 'NR2C2',
#         'NR2F1(var.2)', 'PLAG1', 'PPARD', 'RARA::RXRA', 'RARA::RXRG',
#         'REL', 'RELA', 'RXRB', 'RXRG', 'STAT1', 'STAT3', 'TFAP2A(var.3)',
#         'TFAP2B(var.3)', 'TFAP2C(var.3)', 'TFAP4', 'THRB', 'VDR', 'ZNF449',
#         'ZNF682'], dtype=object),
#  'ILK': array(['FOXH1', 'HOXB6', 'IKZF1', 'IRF1', 'LHX5', 'NKX6-1', 'NR2C2',
#         'NR2F1(var.2)', 'PPARD', 'RXRG', 'TCF21(var.2)', 'THRB', 'USF1',
#         'USF2', 'ZNF135', 'ZNF24', 'ZNF354C', 'ZNF460'], dtype=object),
#  'AGAP2': array(['KLF10', 'KLF11', 'KLF13', 'KLF14', 'KLF16', 'KLF3', 'KLF4',
#         'KLF6', 'KLF9', 'MEF2A', 'MEF2B', 'MEF2C', 'MEF2D', 'NFATC3',
#         'RARA', 'SP1', 'SP3', 'SP4', 'SP8', 'TEAD1', 'TEAD2', 'TEAD3',
#         'TEAD4', 'ZNF135', 'ZNF354C', 'ZNF384', 'ZNF460', 'ZNF682'],
#        dtype=object),
#  'VAV3': array(['ESR1', 'ESR2', 'IRF4', 'IRF7', 'IRF8', 'IRF9', 'KLF10', 'PAX5',
#         'REST', 'SMAD2::SMAD3::SMAD4', 'SOX13', 'SOX2', 'SOX4', 'SOX8',
#         'SOX9', 'SP1', 'ZNF384'], dtype=object),
#  'VIM': array(['BSX', 'LHX2', 'MAZ', 'MEF2A', 'MSX2', 'MZF1(var.2)', 'NFATC2',
#         'PLAG1', 'RAX2', 'SHOX', 'TBX20', 'TBX21', 'THAP11', 'ZBTB33',
#         'ZKSCAN5', 'ZNF135', 'ZNF148', 'ZNF317', 'ZNF354C', 'ZNF460'],
#        dtype=object),
#  'MAPK8': array(['EHF', 'ELF1', 'ELF3', 'ETV1', 'ETV4', 'FOXD2', 'FOXE1', 'GABPA',
#         'GLI2', 'GLI3', 'PHOX2B', 'RBPJ', 'RREB1', 'STAT3', 'ZBTB26',
#         'ZNF354C', 'ZNF460'], dtype=object),
#  'ITGB7': array(['ATOH1(var.2)', 'BACH1', 'BHLHA15(var.2)', 'FERD3L', 'FOXN3',
#         'HOXB4', 'HOXD4', 'INSM1', 'MAFK', 'MEIS1', 'MEIS3', 'MGA', 'MSC',
#         'MYF5', 'MYF6', 'MYOD1', 'NFE2L1', 'NFIA', 'NFIC::TLX1', 'PRDM4',
#         'RBPJ', 'SNAI1', 'SNAI3', 'TAL1::TCF3', 'TBX1', 'TBX15', 'TBX18',
#         'TBX4', 'TBX5', 'TFAP4', 'ZBTB26', 'ZKSCAN5', 'ZNF354C'],
#        dtype=object),
#  'PTPN1': array(['IRF1', 'IRF3', 'IRF4', 'IRF7', 'IRF8', 'IRF9', 'KLF4', 'KLF5',
#         'MEF2A', 'MEF2B', 'MEF2D', 'NFATC2', 'POU6F1(var.2)', 'POU6F2',
#         'RARA', 'SREBF1(var.2)', 'STAT1::STAT2', 'TBX3', 'ZNF135',
#         'ZNF354C', 'ZNF384', 'ZNF460'], dtype=object),
#  'FHL2': array(['MXI1', 'MZF1', 'NR1D1', 'STAT3', 'ZBTB12', 'ZKSCAN5'],
#        dtype=object),
#  'NISCH': array(['EBF3', 'GLIS1', 'GLIS2', 'GLIS3', 'IRF5', 'KLF10', 'KLF11',
#         'KLF16', 'KLF3', 'KLF4', 'KLF5', 'KLF9', 'NFATC2', 'PBX1', 'SP2',
#         'SP3', 'SP9', 'ZBTB26', 'ZNF148', 'ZNF740', 'ZSCAN4'], dtype=object),
#  'PLCG1': array(['EWSR1-FLI1', 'FOXE1', 'FOXF2', 'FOXG1', 'FOXI1', 'FOXL1', 'FOXN3',
#         'FOXO3', 'FOXO4', 'FOXO6', 'FOXP3', 'IRF1', 'NR1H2::RXRA', 'NR2C2',
#         'NR2C2(var.2)', 'NR2F1', 'NR2F1(var.2)', 'NR3C1', 'NR3C2',
#         'PPARA::RXRA', 'PPARD', 'REST', 'RORA(var.2)', 'RORC', 'RXRB',
#         'RXRG', 'SPI1', 'SPIB', 'SREBF1', 'THAP1', 'THRB', 'ZNF384'],
#        dtype=object),
#  'PLD1': array(['CDX2', 'NR2C2(var.2)', 'SOX21', 'TFAP2A(var.3)', 'TFAP2B(var.3)'],
#        dtype=object),
#  'PTPRF': array(['EBF3', 'EGR1', 'EGR3', 'IRF1', 'IRF2', 'IRF3', 'KLF10', 'KLF11',
#         'KLF13', 'KLF14', 'KLF16', 'KLF5', 'KLF6', 'KLF9', 'MEIS1',
#         'RUNX2', 'RUNX3', 'SP1', 'SP2', 'SP3', 'SP4', 'SP9',
#         'STAT1::STAT2', 'VDR', 'ZNF384'], dtype=object),
#  'GIT1': array(['BACH2', 'BACH2(var.2)', 'FOS::JUN', 'FOS::JUND', 'FOSB::JUNB',
#         'FOSL1', 'FOSL1::JUN', 'FOSL1::JUNB', 'FOSL1::JUND', 'FOSL2',
#         'FOSL2::JUN', 'FOSL2::JUNB', 'FOSL2::JUND', 'HNF4A',
#         'HNF4A(var.2)', 'HNF4G', 'JUN(var.2)', 'JUN::JUNB', 'NFE2',
#         'NR1H2::RXRA', 'PPARD', 'RFX3', 'RXRB', 'RXRG', 'STAT1::STAT2',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'DLC1': array(['BARX1', 'EGR1', 'FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3',
#         'KLF9', 'NFATC2', 'RARB(var.3)', 'RARG(var.3)', 'RREB1',
#         'RXRB(var.2)', 'XBP1', 'ZSCAN4'], dtype=object),
#  'FBLIM1': array(['DMRT3', 'EGR1', 'FOS', 'FOS::JUN', 'FOS::JUNB', 'FOS::JUND',
#         'FOSB::JUNB', 'FOSL1', 'FOSL1::JUN', 'FOSL1::JUNB', 'FOSL1::JUND',
#         'FOSL2', 'FOSL2::JUN', 'FOSL2::JUNB', 'FOSL2::JUND', 'FOXI1',
#         'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3', 'IRF3', 'JUNB', 'JUND',
#         'KLF15', 'KLF16', 'NFATC2', 'NFATC3', 'NFE2', 'PRDM1', 'RREB1',
#         'SP9', 'VEZF1', 'ZBTB7C', 'ZNF135', 'ZNF148', 'ZNF740'],
#        dtype=object),
#  'TLN1': array(['EBF3', 'EHF', 'ELF3', 'ELF5', 'GATA2', 'GATA4', 'GATA5', 'IRF1',
#         'KLF9', 'NKX6-3', 'SPI1', 'SPIC', 'ZFP42', 'ZNF354C', 'ZNF384'],
#        dtype=object),
#  'INPP5D': array(['KLF14', 'MEF2A', 'MGA', 'PBX3', 'POU6F2', 'SNAI2', 'SOX4', 'TBX1',
#         'TBX15', 'TBX4', 'TBX5', 'TCF7L1', 'VSX1', 'ZNF135', 'ZNF384',
#         'ZNF460'], dtype=object),
#  'ARHGAP26': array(['ATF4', 'BACH2(var.2)', 'DLX6', 'EOMES', 'EWSR1-FLI1', 'FOXH1',
#         'GATA2', 'GATA3', 'GATA6', 'HAND2', 'NEUROD1', 'NEUROG2(var.2)',
#         'PITX2', 'RHOXF1', 'TBR1', 'ZNF341', 'ZNF354C'], dtype=object),
#  'CTTN': array(['ASCL1(var.2)', 'E2F7', 'E2F8', 'FOXN3', 'KLF9', 'MEIS2(var.2)',
#         'NFATC2', 'PROP1', 'RREB1', 'RUNX3', 'SRY', 'TCF4', 'USF1', 'USF2',
#         'VDR', 'ZNF354C', 'ZNF652', 'ZSCAN4'], dtype=object),
#  'PPFIA1': array(['ATF2', 'ATF3', 'ATF7', 'CREB1', 'DLX6', 'ETV4', 'EWSR1-FLI1',
#         'FOS::JUN(var.2)', 'FOSB::JUN', 'FOSB::JUNB(var.2)',
#         'FOSL2::JUN(var.2)', 'FOSL2::JUNB(var.2)', 'FOSL2::JUND(var.2)',
#         'GBX1', 'JDP2(var.2)', 'JUN', 'JUN::JUNB(var.2)', 'JUNB(var.2)',
#         'JUND(var.2)', 'MAZ', 'RARA::RXRA', 'SREBF1(var.2)', 'TEAD2',
#         'ZNF148', 'ZNF263', 'ZNF384', 'ZNF740'], dtype=object),
#  'ITGA6': array(['ARNT::HIF1A', 'FOXD1', 'FOXI1', 'FOXL1', 'FOXO4', 'FOXO6',
#         'FOXP3', 'KLF10', 'KLF11', 'KLF16', 'KLF17', 'KLF2', 'KLF4',
#         'KLF5', 'KLF9', 'NFYA', 'NFYC', 'SP1', 'SP2', 'SP3', 'SP4'],
#        dtype=object),
#  'HAX1': array(['ATOH7', 'BHLHE22', 'BHLHE23', 'EGR1', 'FOXA1', 'FOXD1', 'FOXI1',
#         'FOXL1', 'FOXO4', 'FOXO6', 'FOXP1', 'FOXP3', 'HIC2', 'KLF4', 'MGA',
#         'NEUROD2', 'NFKB1', 'NR2F1', 'OLIG1', 'OLIG2', 'OLIG3', 'SMAD3',
#         'SMAD5', 'TAL1::TCF3', 'TBX1', 'TBX15', 'TBX4', 'TBX5',
#         'TFAP4(var.2)', 'ZNF135', 'ZNF263', 'ZNF354C', 'ZNF460'],
#        dtype=object),
#  'MAPK1': array(['ATF2', 'FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3', 'MEF2A',
#         'NFATC2', 'NR1I2', 'SNAI2', 'STAT1::STAT2', 'ZNF135', 'ZNF140',
#         'ZNF354C', 'ZNF384', 'ZNF460'], dtype=object),
#  'PPM1F': array(['FOXH1', 'FOXI1', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP3', 'NR1H4',
#         'REST', 'VEZF1', 'VSX1', 'ZNF148', 'ZNF341', 'ZNF354C', 'ZNF740'],
#        dtype=object),
#  'SLC16A3': array(['EGR1', 'ESR1', 'IRF1', 'KLF15', 'KLF16', 'KLF5', 'MEF2A', 'NR1H4',
#         'POU2F2', 'POU2F3', 'POU3F2', 'POU5F1', 'PRDM1', 'RFX2', 'RFX4',
#         'RFX5', 'SP2', 'SP3', 'SP8', 'SP9', 'STAT1', 'STAT3',
#         'TCF12(var.2)', 'TCF3', 'TWIST1', 'ZBTB18', 'ZNF135', 'ZNF148',
#         'ZNF341', 'ZNF384', 'ZNF460'], dtype=object),
#  'SRC': array(['BHLHE22(var.2)', 'KLF2', 'KLF4', 'RREB1', 'TFAP4(var.2)',
#         'ZKSCAN5', 'ZNF528', 'ZSCAN4'], dtype=object),
#  'PTPN12': array(['HIC2', 'IKZF1', 'KLF9', 'SNAI2', 'SREBF1(var.2)', 'ZNF135',
#         'ZNF460'], dtype=object),
#  'SOS1': array(['CEBPA', 'CEBPD', 'HES6', 'HNF4A', 'HNF4A(var.2)', 'HNF4G',
#         'KLF13', 'KLF15', 'KLF16', 'NRF1', 'SNAI1', 'SNAI3', 'ZNF148',
#         'ZNF274', 'ZNF354C'], dtype=object),
#  'TSPAN1': array(['ALX3', 'BARX2', 'FOXA1', 'FOXC2', 'HOXB13', 'IRF1', 'KLF17',
#         'KLF5', 'MEF2A', 'MIXL1', 'NR2C2', 'ONECUT1', 'ONECUT2', 'ONECUT3',
#         'PPARD', 'PRRX1', 'RARA(var.2)', 'RARA::RXRG', 'SOX15', 'SOX21',
#         'SRY', 'THRB', 'UNCX', 'ZNF384'], dtype=object),
#  'MYOM1': array(['ATF2', 'BARX1', 'BSX', 'CDX2', 'CREB1', 'DLX5', 'DLX6', 'EHF',
#         'ELF1', 'ELF3', 'EMX2', 'EN1', 'ETV1', 'ETV4', 'GABPA', 'GBX2',
#         'HESX1', 'HNF4A', 'HOXA10', 'HOXA6', 'HOXB3', 'HOXB6', 'HOXB7',
#         'HOXB8', 'HOXC8', 'HOXD8', 'HOXD9', 'ISL2', 'ISX', 'LBX2', 'LHX1',
#         'LHX2', 'LHX5', 'LHX9', 'LMX1A', 'MEOX2', 'MIXL1', 'MNX1', 'MSX1',
#         'MSX2', 'NKX6-1', 'NKX6-2', 'NR4A2', 'PDX1', 'PRRX1', 'PRRX2',
#         'RAX', 'RAX2', 'SHOX', 'TEAD1', 'TEAD2', 'TEAD4', 'TLX2', 'UNCX',
#         'VAX1', 'VAX2', 'ZNF263'], dtype=object),
#  'CYTH2': array(['CTCF', 'CTCFL', 'DLX5', 'KLF13', 'KLF9', 'MAFG', 'MYB', 'NFIC',
#         'NR1H2::RXRA', 'NRL', 'PPARA::RXRA', 'REST', 'RORA(var.2)',
#         'SNAI3', 'ZNF135', 'ZNF16'], dtype=object),
#  'ABI2': array(['GATA3', 'GATA6', 'NR1D2', 'PBX3', 'SOX21', 'ZNF136', 'ZNF384',
#         'ZNF460'], dtype=object),
#  'ABI3': array(['HOXB6', 'KLF2', 'LHX5', 'NKX6-1', 'RARA', 'TWIST1', 'ZBTB6',
#         'ZNF135', 'ZNF460'], dtype=object),
#  'ABL1': array(['FOXI1', 'FOXK2', 'FOXL1', 'FOXO4', 'FOXO6', 'FOXP1', 'FOXP3',
#         'HOXC13', 'KLF10', 'KLF4', 'KLF5', 'KLF9', 'MEIS1', 'MEIS3',
#         'MSANTD3', 'NFYA', 'SP1', 'SP4', 'ZNF135'], dtype=object),
#  'CIB2': array(['ESRRA', 'ESRRB', 'EWSR1-FLI1', 'FOXA1', 'FOXA2', 'FOXA3', 'FOXB1',
#         'FOXC1', 'FOXD1', 'FOXI1', 'FOXK2', 'FOXL1', 'FOXO4', 'FOXO6',
#         'FOXP1', 'FOXP3', 'HES5', 'HES7', 'IRF1', 'NHLH1', 'NR2F1',
#         'NR2F2', 'NR5A1', 'PITX2', 'PLAG1', 'RHOXF1', 'ZBTB6', 'ZNF263',
#         'ZNF384', 'ZNF460'], dtype=object),
#  'ACTN1': array(['CTCF', 'KLF16', 'KLF4', 'KLF5', 'KLF9', 'MGA', 'MSANTD3',
#         'NFATC2', 'NFATC3', 'NR2F2', 'RREB1', 'TBX1', 'TBX15', 'TBX3',
#         'TBX4', 'TBX5', 'TCF12(var.2)', 'TCF3', 'THAP11', 'ZNF136',
#         'ZNF274', 'ZSCAN4'], dtype=object),
#  'VCL': array(['ELF1', 'ETV1', 'ETV4', 'EWSR1-FLI1', 'GABPA', 'KLF17',
#         'POU6F1(var.2)', 'ZBTB7A', 'ZNF140'], dtype=object),
#  'AKT1': array(['ATOH1(var.2)', 'BHLHA15(var.2)', 'CTCF', 'EBF1', 'EWSR1-FLI1',
#         'FERD3L', 'GSC2', 'HIC2', 'OTX2', 'PBX3', 'PITX3'], dtype=object),
#  'NEDD9': array(['GATA1', 'INSM1', 'LEF1', 'NFYB', 'RARA::RXRA', 'SP8', 'THAP11',
#         'TP53', 'ZNF263'], dtype=object),
#  'ZFYVE21': array(['FOXN3', 'HOXA4', 'HOXC4', 'HOXD4', 'INSM1', 'KLF10', 'KLF17',
#         'KLF9', 'MAX', 'MAX::MYC', 'MEF2A', 'MEF2B', 'MEF2C', 'MEF2D',
#         'MEIS1', 'MEIS2', 'MNT', 'PBX3', 'ZNF354C'], dtype=object),
#  'INSR': array(['ATOH7', 'CDX1', 'CDX4', 'ELF2', 'HOXA13', 'HOXA4', 'HOXB13',
#         'HOXD9', 'HSF4', 'MSGN1', 'MYB', 'NEUROD2', 'OLIG2', 'OLIG3',
#         'TCF21(var.2)', 'ZFP42'], dtype=object),
#  'PDPK1': array(['ETS2', 'KLF6', 'NFATC3', 'NFATC4', 'NRF1', 'NRL', 'THAP11', 'YY1',
#         'ZFP42', 'ZNF143', 'ZNF263'], dtype=object),
#  'GIT2': array(['ARNT::HIF1A', 'ASCL1(var.2)', 'ATF2', 'BARX2', 'ESR2',
#         'EWSR1-FLI1', 'IRF1', 'MAF', 'MEF2A', 'PITX2', 'PRDM4', 'RHOXF1',
#         'SNAI2', 'SOX15', 'TBX18', 'TCF3', 'THRB(var.3)', 'ZNF135',
#         'ZNF263', 'ZNF354C', 'ZNF384', 'ZNF449', 'ZNF460', 'ZNF75D'],
#        dtype=object),
#  'NUDT16L1': array(['IKZF1', 'IRF2', 'IRF3', 'KLF17', 'KLF9', 'MAF', 'MAFA', 'MAFK',
#         'MGA', 'MTF1', 'NFATC2', 'NFATC3', 'PRDM1', 'SPI1', 'TBX1',
#         'TBX15', 'TBX18', 'TBX20', 'TBX4', 'TBX5', 'ZNF354C'], dtype=object),
#  'PRKACA': array(['CEBPA', 'CEBPD', 'EWSR1-FLI1', 'GATA4', 'HLF', 'IRF1', 'NFATC2',
#         'NFATC3', 'NFATC4', 'NFIL3', 'OTX2', 'PHOX2B', 'PRDM1', 'RELA',
#         'SPI1', 'STAT1::STAT2', 'ZKSCAN5', 'ZNF16', 'ZNF263', 'ZNF652'],
#        dtype=object),
#  'CASS4': array(['ARNT::HIF1A', 'ASCL1', 'ATF2', 'ATF3', 'CDX1', 'CREB1', 'E2F7',
#         'FOS::JUN(var.2)', 'FOSB::JUN', 'FOSB::JUNB(var.2)',
#         'FOSL2::JUN(var.2)', 'FOSL2::JUNB(var.2)', 'FOSL2::JUND(var.2)',
#         'FOXE1', 'FOXN3', 'JDP2(var.2)', 'JUN', 'JUNB(var.2)',
#         'JUND(var.2)', 'MYOG', 'NFATC2', 'PKNOX1'], dtype=object),
#  'PTPRA': array(['HES1', 'HES2', 'MEF2A', 'MEF2B', 'MEF2C', 'MEF2D', 'SREBF1',
#         'ZBTB6', 'ZNF135', 'ZNF317', 'ZNF384', 'ZNF460'], dtype=object),
#  'TRPM7': array(['EGR1', 'EGR4', 'HES6', 'HIC2', 'HOXB6', 'IRF1', 'IRF7', 'KLF11',
#         'KLF16', 'KLF9', 'LHX5', 'MEIS1', 'MEIS2', 'MYBL2', 'NFATC2',
#         'NFIB', 'NFIC(var.2)', 'NFIC::TLX1', 'NKX6-1', 'POU1F1', 'POU2F1',
#         'POU2F2', 'POU2F3', 'POU3F1', 'POU3F2', 'POU3F3', 'POU3F4',
#         'POU5F1', 'POU5F1B', 'SMAD2::SMAD3::SMAD4', 'SP3', 'SP8', 'SP9',
#         'SREBF1', 'SREBF2', 'ZFP57', 'ZNF384'], dtype=object),
#  'PTPN2': array(['EGR1', 'EGR3', 'KLF15', 'KLF4', 'KLF5', 'LEF1', 'POU1F1',
#         'POU4F1', 'SP1', 'SP2', 'SP4'], dtype=object),
#  'LDB3': array(['EWSR1-FLI1', 'FOXN3', 'HNF4A', 'HNF4G', 'MAZ', 'MGA',
#         'SMAD2::SMAD3::SMAD4', 'SNAI1', 'SNAI2', 'SNAI3', 'SRY',
#         'STAT1::STAT2', 'TBX1', 'TBX15', 'TBX18', 'TBX20', 'TBX4', 'TBX5',
#         'ZBTB6', 'ZNF140', 'ZNF460'], dtype=object),
#  'INPPL1': array(['DUX4', 'HIC2', 'MEF2A', 'NRF1', 'RFX7', 'TFAP2A', 'TFAP2B(var.2)',
#         'TFAP2C(var.2)', 'TFAP2E', 'ZBTB12', 'ZBTB33', 'ZNF135', 'ZNF282',
#         'ZNF354C', 'ZNF384', 'ZNF460'], dtype=object),
#  'PTPN11': array(['DLX5', 'EGR4', 'GFI1', 'HIC2', 'HOXA7', 'HOXB8', 'HOXD8', 'LHX1',
#         'MAZ', 'MZF1', 'MZF1(var.2)', 'NEUROD1', 'NEUROG2(var.2)', 'NR1H4',
#         'NR2C2(var.2)', 'PRDM4', 'ZNF135', 'ZNF24', 'ZNF384', 'ZNF460'],
#        dtype=object),
#  'ITGB3': array(['GLI2', 'GLI3', 'NRL', 'ZKSCAN5', 'ZNF148', 'ZNF75D'], dtype=object),
#  'OSTF1': array(['E2F6', 'MTF1', 'NFIA', 'NFIC', 'NFIX', 'TBX18', 'VEZF1', 'ZBTB26'],
#        dtype=object),
#  'PLAUR': array(['E2F8', 'IKZF1', 'IRF1', 'PRDM1', 'RREB1', 'TEAD1', 'TEAD2',
#         'TEAD3', 'TEAD4', 'TP53', 'TP63', 'TP73', 'ZNF384'], dtype=object),
#  'CD47': array(['HOXB4', 'HOXD4', 'IRF1', 'IRF7', 'IRF8', 'ISX', 'KLF4', 'LBX1',
#         'LEF1', 'LHX9', 'MYC', 'MYCN', 'NKX6-2', 'PRRX1', 'PRRX2', 'RREB1',
#         'TCF7L1', 'TCF7L2', 'TFAP2A(var.2)', 'TFAP2B', 'TFAP2B(var.2)',
#         'TFAP2C', 'UNCX', 'ZFP42', 'ZNF148'], dtype=object),
#  'LPXN': array(['EBF3', 'VDR', 'ZNF135', 'ZNF354C', 'ZNF384'], dtype=object),
#  'CORO2A': array(['BACH2', 'JUN::JUNB', 'LEF1', 'MYCN', 'SCRT2', 'TCF7', 'TCF7L1',
#         'TCF7L2', 'ZNF140', 'ZNF684'], dtype=object),
#  'SPTLC1': array(['FOXE1', 'GATA3', 'IRF1', 'ISX', 'LBX1', 'LHX9', 'NKX6-2', 'PBX3',
#         'PRDM1', 'PRRX1', 'PRRX2', 'SPIC', 'TBXT', 'UNCX', 'ZBTB6',
#         'ZNF135', 'ZNF460'], dtype=object),
#  'MARCKS': array(['ASCL1', 'ATOH1(var.2)', 'BHLHA15(var.2)', 'E2F8', 'MAZ', 'MYOG',
#         'MZF1(var.2)', 'NHLH1', 'NHLH2', 'OSR1', 'PITX1', 'SPI1', 'ZNF148',
#         'ZNF282'], dtype=object),
#  'PTPRO': array(['KLF10', 'KLF11', 'KLF16', 'KLF9', 'NFATC2', 'RARB(var.3)',
#         'RARG(var.3)', 'RREB1', 'SRY'], dtype=object),
#  'NDEL1': array(['GSX1', 'IRF5', 'ISX', 'LBX1', 'LHX9', 'NKX6-2', 'NKX6-3', 'NOTO',
#         'PRRX1', 'PRRX2', 'UNCX', 'YY2', 'ZNF354C', 'ZNF384'], dtype=object),
#  'LYN': array(['MAFK', 'MGA', 'NEUROG2(var.2)', 'PRDM4', 'SMAD2::SMAD3::SMAD4',
#         'STAT1::STAT2', 'TBX1', 'TBX15', 'TBX3', 'TBX4', 'TBX5', 'TBX6',
#         'ZNF135', 'ZNF354C', 'ZNF384', 'ZNF460'], dtype=object),
#  'ILKAP': array(['DMRTC2', 'GRHL2', 'IRF1', 'KLF14', 'NFATC2', 'NR3C1', 'NR3C2',
#         'OSR2', 'THAP1', 'ZNF384', 'ZNF449'], dtype=object),
#  'MAPK8IP3': array(['EBF1', 'LEF1', 'NR2C2', 'NR2F1(var.2)', 'ONECUT1', 'ONECUT2',
#         'ONECUT3', 'PLAG1', 'THRB', 'ZNF354C'], dtype=object),
#  'DOCK1': array(['ALX3', 'ARGFX', 'DMRT3', 'E2F6', 'EWSR1-FLI1', 'FOXN3', 'ISX',
#         'KLF17', 'KLF5', 'LBX1', 'LHX9', 'MAZ', 'MIXL1', 'MSGN1', 'MTF1',
#         'NKX6-2', 'PRRX1', 'PRRX2', 'SP2', 'UNCX', 'ZNF148'], dtype=object),
#  'SLC9A1': array(['ATF4', 'EGR1', 'EGR3', 'ESRRA', 'ESRRB', 'FOSL2::JUND(var.2)',
#         'GRHL2', 'IRF1', 'JUN', 'JUND(var.2)', 'KLF11', 'KLF15', 'KLF5',
#         'MEF2A', 'MEF2C', 'NR4A2', 'NR5A1', 'SP2', 'SP3', 'SP9', 'ZBTB14',
#         'ZNF140', 'ZNF384'], dtype=object),
#  'FERMT2': array(['BHLHA15(var.2)', 'FOXN3', 'NHLH1', 'ZNF140', 'ZNF684'],
#        dtype=object),
#  'RHOU': array(['GATA2', 'GATA3', 'GATA6', 'HIC2', 'KLF10', 'KLF17', 'SPI1',
#         'SPIB', 'TCF7L1', 'TFAP2A', 'ZNF135', 'ZNF75D'], dtype=object),
#  'ITGA2': array(['CREB1', 'FOSL2::JUND(var.2)', 'IKZF1', 'JUND(var.2)', 'NFATC2'],
#        dtype=object),
#  'PIK3CA': array(['GLIS1', 'HNF4A', 'HNF4G', 'NFYB', 'PAX6', 'RUNX3', 'ZEB1',
#         'ZNF460'], dtype=object),
#  'PARVA': array(['HOXA1', 'HOXA13', 'HOXA5', 'HOXB5', 'HOXC8', 'MAZ', 'NR6A1',
#         'POU6F1(var.2)', 'RARA::RXRA', 'TEAD3', 'ZBTB32', 'ZNF148',
#         'ZNF740'], dtype=object),
#  'SYNM': array(['EHF', 'ELF3', 'ESR2', 'ESRRA', 'ESRRB', 'FOXB1', 'GATA5', 'HOXA4',
#         'HOXB4', 'HOXD4', 'ISX', 'LBX1', 'LHX9', 'NEUROD2', 'NKX6-2',
#         'NR2F2', 'NR5A1', 'PRRX1', 'PRRX2', 'RARB(var.3)', 'RXRG(var.2)',
#         'THRB(var.3)', 'UNCX', 'ZNF148'], dtype=object),
#  'ROCK1': array(['GATA3', 'KLF10', 'KLF16', 'KLF17', 'KLF4', 'KLF5', 'KLF9', 'NFYA',
#         'NFYC', 'SP1', 'ZNF354C'], dtype=object),
#  'TIAM1': array(['CEBPG(var.2)', 'FOXN3', 'IRF4', 'IRF5', 'IRF8', 'KLF16', 'KLF4',
#         'KLF5', 'MAZ', 'MEF2A', 'NR2C2', 'PKNOX1', 'RREB1', 'SP1', 'SP4',
#         'ZNF148'], dtype=object),
#  'VAV2': array(['BARX2', 'BCL6B', 'CDX1', 'CDX2', 'CDX4', 'FOS', 'FOS::JUN',
#         'FOS::JUNB', 'FOS::JUND', 'FOSB::JUNB', 'FOSL1', 'FOSL1::JUN',
#         'FOSL1::JUNB', 'FOSL2', 'FOSL2::JUN', 'FOSL2::JUNB', 'FOSL2::JUND',
#         'HNF1A', 'HNF1B', 'HOXA10', 'HOXA13', 'HOXD9', 'JUN(var.2)',
#         'PPARG', 'RBPJ'], dtype=object),
#  'PDE4D': array(['ALX3', 'ARGFX', 'BATF3', 'FOXN3', 'GATA4', 'IKZF1', 'IRF1',
#         'IRF3', 'IRF8', 'IRF9', 'ISX', 'LBX1', 'LHX9', 'NFATC2', 'NKX6-2',
#         'NR1D1', 'NR1D2', 'PRDM4', 'PRRX1', 'PRRX2', 'RBPJ', 'RORA(var.2)',
#         'SPIC', 'UNCX', 'ZBTB12', 'ZNF528'], dtype=object),
#  'NCK2': array(['CTCFL', 'NR2C2(var.2)', 'NR2F1(var.3)', 'OSR2', 'RARA(var.2)',
#         'RARA::RXRA', 'RARA::RXRG', 'SOX13', 'ZNF16', 'ZNF682'],
#        dtype=object),
#  'ITGA9': array(['EWSR1-FLI1', 'ISL2', 'MXI1', 'SMAD2::SMAD3::SMAD4', 'TFAP2A',
#         'TFAP2A(var.2)', 'TFAP2C(var.2)', 'THAP11'], dtype=object),
#  'ADAM12': array(['FOXB1', 'FOXC1', 'FOXD2', 'NFATC2', 'PPARG', 'SNAI1',
#         'TCF12(var.2)', 'TCF3', 'ZBTB26', 'ZNF384'], dtype=object),
#  'PEAK1': array(['DLX6', 'FOXH1', 'HOXB6', 'KLF4', 'KLF5', 'LHX5', 'NKX6-1', 'PAX3',
#         'VSX1', 'ZNF341', 'ZNF382'], dtype=object),
#  'PRKCA': array(['CREB1', 'IRF1', 'KLF2', 'KLF6', 'KLF9', 'MGA',
#         'SMAD2::SMAD3::SMAD4', 'SNAI2', 'TBX1', 'TBX15', 'TBX4', 'TBX5',
#         'TCF7', 'TFAP2A(var.3)', 'TFAP2B(var.3)', 'TFAP2C(var.3)',
#         'THAP11', 'ZBTB6', 'ZNF384'], dtype=object)}

# %% [markdown]
# # Confirm using ChIP-seq
